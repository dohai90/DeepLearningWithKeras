# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

import numpy as np
import keras
import json
import matplotlib.pyplot as plt
import time
import seaborn

from PIL import Image
from IPython import display

# %matplotlib inline
seaborn.set()

# %% [markdown]
# # Setting up the game

# %%
class Catch(object):
    """ This is a actual game """
    def __init__(self, grid_size=10):
        self.grid_size = grid_size
        self.reset()
        
    def _update_state(self, action):
        """
        Inputs: action and states
        Outputs: new states and reward
        """
        state = self.state
        if action == 0:
            action = -1
        elif action == 1:
            action = 0
        else:
            action = 1
            
        f0, f1, basket = state[0]
        new_basket = min(max(1, basket + action), self.grid_size - 1)
        f0 += 1
        out = np.asarray([f0, f1, new_basket])
        out = out[np.newaxis]
        
        assert len(out.shape) == 2
        self.state = out
        
    def _draw_state(self):
        im_size = (self.grid_size, )*2
        state = self.state[0]
        canvas = np.zeros(im_size)
        canvas[state[0], state[1]] = 1 # draw fruit
        canvas[-1, state[2]-1:state[2]+2] = 1 # draw basket
        return canvas
    
    def _get_reward(self):
        fruit_row, fruit_col, basket = self.state[0]
        if fruit_row == self.grid_size-1:
            if abs(fruit_col - basket) <= 1:
                return 1
            else:
                return -1
        else:
            return 0
        
    def _is_over(self):
        if self.state[0, 0] == self.grid_size - 1:
            return True
        else:
            return False
        
    def observe(self):
        canvas = self._draw_state()
        return canvas.reshape((1, -1))
    
    def act(self, action):
        self._update_state(action)
        reward = self._get_reward()
        game_over = self._is_over()
        return self.observe(), reward, game_over
    
    def reset(self):
        n = np.random.randint(0, self.grid_size-1, size=1)
        m = np.random.randint(1, self.grid_size-2, size=1)
        self.state = np.asarray([0, n, m])[np.newaxis]

# %%
# Here we define some variables used for the game and rendering later
last_frame_time = 0
translate_action = ["Left","Stay","Right","Create Ball","End Test"]
grid_size = 10

# %%
def display_screen(action, points, input_t):
    global last_frame_time
    print('Action %s, Points: %d' % (translate_action[action], points))
    if 'End'not in translate_action[action]:
        plt.imshow(input_t.reshape((grid_size, )*2), interpolation='none', cmap='gray')
        display.clear_output(wait=True)
        display.display(plt.gcf())
        plt.show()
    last_frame_time = set_max_fps(last_frame_time)
    
def set_max_fps(last_frame_time, FPS=1):
    current_mili_time = lambda: int(round(time.time() * 1000))
    sleep_time = 1. / FPS - (current_mili_time() - last_frame_time)
    if sleep_time > 0:
        time.sleep(sleep_time)
    return current_mili_time()

# %%
class ExperienceReplay(object):
    """
    During gameplay all the experiences <s, a, r, s'> are stored in a replay memory.
    In training, batches of randomly drawn experiences are used to generate the input and target for training
    """
    def __init__(self, max_memory=100, discount=0.9):
        """
        Setup
        max_memory: the maximum number of experiences we want to store
        memory: a list of experiences
        discount: the discount factor for future experience
        
        In the memory the information whether the game ended at the state is stored separately in a nested array
        [...
        [experience, game_over]
        [experience, game_over]
        ...]
        """
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount
        
    def remember(self, states, game_over):
        """ Save a state to memory """
        self.memory.append([states, game_over])
        # remove oldest state in memory
        if len(self.memory) > self.max_memory:
            del self.memory[0]
            
    def get_batch(self, model, batch_size=10):
        # how many experiences do we have?
        len_memory = len(self.memory)
        
        # calculate the number of actions that can possibly be taken in the game
        num_actions = model.output_shape[-1]
        
        # dimensions of the game field
        env_dim = self.memory[0][0][0].shape[1]
        
        # we want to return an input and target vector with inputs from an observed state...
        inputs = np.zeros((min(len_memory, batch_size), env_dim))
        
        # ... and the target r + gamma * max Q(s', a')
        # Note that our target is a matrix, with possible fields not only for the action taken but also
        # for the other possible actions. The actions not take the same value as the prediction to not affect them
        targets = np.zeros((inputs.shape[0], num_actions))
        
        # We draw states to learn from randomly
        for i, idx in enumerate(np.random.randint(0, len_memory, size=inputs.shape[0])):
            """
            Here we load one transition <s, a, r, s'> from memory
            state_t: initial state s
            action_t: action taken a
            reward_t: reward earned r
            state_tp1: the state that follow s'
            """
            state_t, action_t, reward_t, state_tp1 = self.memory[idx][0]
            
            # We also need to know whether the game ended at this state
            game_over = self.memory[idx][1]
            
            # add the state s to the input
            inputs[i:i+1] = state_t
            
            # first we fill the target values with the predictions of the model.
            # they will not be affected by training 
            targets[i] = model.predict(state_t)[0]
            
            # Here Q_sa is max_a' Q(s', a')
            Q_sa = np.max(model.predict(state_tp1)[0])
            
            # if the game is over, the reward is the final reward
            if game_over:
                targets[i, action_t] = reward_t
            else:
                targets[i, action_t] = reward_t + self.discount * Q_sa
                
        return inputs, targets

# %%
def baseline_model(grid_size, num_actions, hidden_size):
    model = keras.Sequential()
    model.add(keras.layers.Dense(hidden_size, input_shape=(grid_size**2, ), activation='relu'))
    model.add(keras.layers.Dense(hidden_size, activation='relu'))
    model.add(keras.layers.Dense(num_actions))
    
    model.compile(optimizer=keras.optimizers.SGD(lr=0.1),
                  loss='mse')
    return model

# %%
# building the model
epsilon = 0.1
num_actions = 3
hidden_size = 100
grid_size = 10
max_memory = 500
batch_size = 1

# %%
model = baseline_model(grid_size, num_actions, hidden_size)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 20,503
# Trainable params: 20,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define environment / game
env = Catch(grid_size)

# Init experience replay object
exp_replay = ExperienceReplay(max_memory=max_memory)

# %%
def train(model, epochs, verbose=1):
    # train
    # reseting the win counter
    win_cnt = 0
    win_hist = []
    # epochs is the number of game play
    for e in range(epochs):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()
        
        while not game_over:
            # The learner is acting on the last observed game screen
            # input_t is a vector containing representing the game screen
            input_tm1 = input_t
            
            if np.random.rand() <= epsilon:
                action = np.random.randint(0, num_actions, size=1)
            else:
                # q contains the expected rewards for the actions
                q = model.predict(input_tm1)
                # we pick the actionwith the highest expected reward
                action = np.argmax(q[0])
                
            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)
            # if we managed to catch the fruit we add 1 to our win counter
            if reward == 1:
                win_cnt += 1
                
            # Uncomment this to render the game
            #display_screen(action, 3000, inputs[0])
            
            """ The experience <s, a, r, s'> we make during gameplay are our training data.
            Here we first save the last experience, and then load a batch of experiences to train our model"""
            
            # store experience
            exp_replay.remember([input_tm1, action, reward, input_t], game_over)
            
            # load batch of experiences
            inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)
            
            # train model on experiences
            batch_loss = model.train_on_batch(inputs, targets)
            
            loss += batch_loss
            
        if verbose > 0:
            print('Epoch {:03d}/{:03d} | Loss {:.4f} | Win count {}'.format(e, epochs, loss, win_cnt))
        win_hist.append(win_cnt)
    return win_hist

# %%
epochs = 5000
hist = train(model, epochs, verbose=1)
print('Training done!')
# Out:
# Epoch 000/5000 | Loss 0.0126 | Win count 1
# Epoch 001/5000 | Loss 0.0314 | Win count 1
# Epoch 002/5000 | Loss 0.0481 | Win count 1
# Epoch 003/5000 | Loss 0.5598 | Win count 1
# Epoch 004/5000 | Loss 0.1996 | Win count 1
# Epoch 005/5000 | Loss 0.5535 | Win count 1
# Epoch 006/5000 | Loss 0.2284 | Win count 1
# Epoch 007/5000 | Loss 0.0334 | Win count 1
# Epoch 008/5000 | Loss 0.9591 | Win count 1
# Epoch 009/5000 | Loss 0.0730 | Win count 2
# Epoch 010/5000 | Loss 0.1065 | Win count 2
# Epoch 011/5000 | Loss 0.4818 | Win count 2
# Epoch 012/5000 | Loss 0.0342 | Win count 2
# Epoch 013/5000 | Loss 0.2565 | Win count 2
# Epoch 014/5000 | Loss 0.4105 | Win count 2
# Epoch 015/5000 | Loss 0.5222 | Win count 2
# Epoch 016/5000 | Loss 0.0770 | Win count 3
# Epoch 017/5000 | Loss 0.3179 | Win count 3
# Epoch 018/5000 | Loss 0.0981 | Win count 3
# Epoch 019/5000 | Loss 0.2888 | Win count 3
# Epoch 020/5000 | Loss 0.0853 | Win count 4
# Epoch 021/5000 | Loss 0.4896 | Win count 4
# Epoch 022/5000 | Loss 0.4942 | Win count 4
# Epoch 023/5000 | Loss 0.9221 | Win count 5
# Epoch 024/5000 | Loss 0.3095 | Win count 5
# Epoch 025/5000 | Loss 0.2516 | Win count 5
# Epoch 026/5000 | Loss 0.3787 | Win count 5
# Epoch 027/5000 | Loss 0.0231 | Win count 5
# Epoch 028/5000 | Loss 0.2781 | Win count 5
# Epoch 029/5000 | Loss 0.2225 | Win count 5
# Epoch 030/5000 | Loss 0.0509 | Win count 5
# Epoch 031/5000 | Loss 0.4490 | Win count 5
# Epoch 032/5000 | Loss 0.1166 | Win count 5
# Epoch 033/5000 | Loss 0.2258 | Win count 5
# Epoch 034/5000 | Loss 0.1280 | Win count 5
# Epoch 035/5000 | Loss 0.1928 | Win count 5
# Epoch 036/5000 | Loss 0.1359 | Win count 5
# Epoch 037/5000 | Loss 0.2097 | Win count 5
# Epoch 038/5000 | Loss 0.0360 | Win count 5
# Epoch 039/5000 | Loss 0.1384 | Win count 5
# Epoch 040/5000 | Loss 0.0541 | Win count 5
# Epoch 041/5000 | Loss 0.1544 | Win count 5
# Epoch 042/5000 | Loss 0.0585 | Win count 5
# Epoch 043/5000 | Loss 0.1207 | Win count 5
# Epoch 044/5000 | Loss 0.1033 | Win count 5
# Epoch 045/5000 | Loss 0.2668 | Win count 6
# Epoch 046/5000 | Loss 0.0326 | Win count 6
# Epoch 047/5000 | Loss 0.1481 | Win count 6
# Epoch 048/5000 | Loss 0.0164 | Win count 7
# Epoch 049/5000 | Loss 0.0162 | Win count 8
# Epoch 050/5000 | Loss 0.1854 | Win count 8
# Epoch 051/5000 | Loss 0.1962 | Win count 8
# Epoch 052/5000 | Loss 0.1610 | Win count 8
# Epoch 053/5000 | Loss 0.1187 | Win count 9
# Epoch 054/5000 | Loss 0.0186 | Win count 9
# Epoch 055/5000 | Loss 0.0355 | Win count 10
# Epoch 056/5000 | Loss 0.0197 | Win count 11
# Epoch 057/5000 | Loss 0.0142 | Win count 12
# Epoch 058/5000 | Loss 0.3112 | Win count 12
# Epoch 059/5000 | Loss 0.8701 | Win count 12
# Epoch 060/5000 | Loss 0.0467 | Win count 12
# Epoch 061/5000 | Loss 0.0183 | Win count 12
# Epoch 062/5000 | Loss 0.0258 | Win count 13
# Epoch 063/5000 | Loss 0.0117 | Win count 13
# Epoch 064/5000 | Loss 0.4608 | Win count 13
# Epoch 065/5000 | Loss 0.2289 | Win count 14
# Epoch 066/5000 | Loss 0.3325 | Win count 15
# Epoch 067/5000 | Loss 0.1930 | Win count 15
# Epoch 068/5000 | Loss 0.2538 | Win count 16
# Epoch 069/5000 | Loss 0.5940 | Win count 16
# Epoch 070/5000 | Loss 0.2503 | Win count 17
# Epoch 071/5000 | Loss 0.2554 | Win count 17
# Epoch 072/5000 | Loss 0.6263 | Win count 17
# Epoch 073/5000 | Loss 0.3923 | Win count 18
# Epoch 074/5000 | Loss 0.4721 | Win count 18
# Epoch 075/5000 | Loss 0.4066 | Win count 19
# Epoch 076/5000 | Loss 0.1789 | Win count 19
# Epoch 077/5000 | Loss 0.3792 | Win count 20
# Epoch 078/5000 | Loss 0.0195 | Win count 21
# Epoch 079/5000 | Loss 0.0108 | Win count 22
# Epoch 080/5000 | Loss 0.0490 | Win count 23
# Epoch 081/5000 | Loss 0.0244 | Win count 24
# Epoch 082/5000 | Loss 0.0172 | Win count 25
# Epoch 083/5000 | Loss 0.6226 | Win count 26
# Epoch 084/5000 | Loss 0.0977 | Win count 27
# Epoch 085/5000 | Loss 1.0705 | Win count 27
# Epoch 086/5000 | Loss 0.2596 | Win count 27
# Epoch 087/5000 | Loss 0.1188 | Win count 27
# Epoch 088/5000 | Loss 0.0138 | Win count 27
# Epoch 089/5000 | Loss 0.2965 | Win count 27
# Epoch 090/5000 | Loss 0.4962 | Win count 27
# Epoch 091/5000 | Loss 0.4524 | Win count 27
# Epoch 092/5000 | Loss 0.0316 | Win count 27
# Epoch 093/5000 | Loss 0.1129 | Win count 27
# Epoch 094/5000 | Loss 0.1080 | Win count 28
# Epoch 095/5000 | Loss 0.6095 | Win count 28
# Epoch 096/5000 | Loss 0.1581 | Win count 28
# Epoch 097/5000 | Loss 0.8040 | Win count 29
# Epoch 098/5000 | Loss 0.3416 | Win count 29
# Epoch 099/5000 | Loss 1.1063 | Win count 29
# Epoch 100/5000 | Loss 0.3328 | Win count 30
# Epoch 101/5000 | Loss 0.0278 | Win count 31
# Epoch 102/5000 | Loss 0.2997 | Win count 31
# Epoch 103/5000 | Loss 0.0195 | Win count 31
# Epoch 104/5000 | Loss 1.1992 | Win count 31
# Epoch 105/5000 | Loss 0.8673 | Win count 31
# Epoch 106/5000 | Loss 0.2324 | Win count 31
# Epoch 107/5000 | Loss 0.8736 | Win count 32
# Epoch 108/5000 | Loss 0.1753 | Win count 32
# Epoch 109/5000 | Loss 0.1996 | Win count 33
# Epoch 110/5000 | Loss 0.7511 | Win count 33
# Epoch 111/5000 | Loss 0.4872 | Win count 33
# Epoch 112/5000 | Loss 0.5514 | Win count 33
# Epoch 113/5000 | Loss 0.0279 | Win count 34
# Epoch 114/5000 | Loss 0.8030 | Win count 35
# Epoch 115/5000 | Loss 0.2909 | Win count 35
# Epoch 116/5000 | Loss 0.1208 | Win count 36
# Epoch 117/5000 | Loss 0.2346 | Win count 36
# Epoch 118/5000 | Loss 0.1058 | Win count 37
# Epoch 119/5000 | Loss 0.2627 | Win count 37
# Epoch 120/5000 | Loss 0.1072 | Win count 37
# Epoch 121/5000 | Loss 0.7138 | Win count 37
# Epoch 122/5000 | Loss 0.4733 | Win count 38
# Epoch 123/5000 | Loss 1.2232 | Win count 38
# Epoch 124/5000 | Loss 0.3634 | Win count 38
# Epoch 125/5000 | Loss 0.5370 | Win count 38
# Epoch 126/5000 | Loss 0.5673 | Win count 39
# Epoch 127/5000 | Loss 0.0476 | Win count 39
# Epoch 128/5000 | Loss 0.6696 | Win count 39
# Epoch 129/5000 | Loss 0.7389 | Win count 39
# Epoch 130/5000 | Loss 0.0915 | Win count 39
# Epoch 131/5000 | Loss 0.3872 | Win count 39
# Epoch 132/5000 | Loss 0.6300 | Win count 39
# Epoch 133/5000 | Loss 0.5663 | Win count 40
# Epoch 134/5000 | Loss 1.3372 | Win count 40
# Epoch 135/5000 | Loss 0.4402 | Win count 40
# Epoch 136/5000 | Loss 0.0333 | Win count 40
# Epoch 137/5000 | Loss 0.2936 | Win count 40
# Epoch 138/5000 | Loss 0.8908 | Win count 40
# Epoch 139/5000 | Loss 0.2127 | Win count 40
# Epoch 140/5000 | Loss 0.2188 | Win count 41
# Epoch 141/5000 | Loss 0.2229 | Win count 42
# Epoch 142/5000 | Loss 0.2415 | Win count 43
# Epoch 143/5000 | Loss 0.7652 | Win count 43
# Epoch 144/5000 | Loss 0.3057 | Win count 43
# Epoch 145/5000 | Loss 0.2776 | Win count 43
# Epoch 146/5000 | Loss 0.2636 | Win count 43
# Epoch 147/5000 | Loss 0.2630 | Win count 43
# Epoch 148/5000 | Loss 0.0195 | Win count 43
# Epoch 149/5000 | Loss 0.0327 | Win count 43
# Epoch 150/5000 | Loss 0.0855 | Win count 43
# Epoch 151/5000 | Loss 0.7427 | Win count 43
# Epoch 152/5000 | Loss 0.0925 | Win count 43
# Epoch 153/5000 | Loss 0.5160 | Win count 43
# Epoch 154/5000 | Loss 0.6203 | Win count 44
# Epoch 155/5000 | Loss 0.3667 | Win count 44
# Epoch 156/5000 | Loss 0.3445 | Win count 44
# Epoch 157/5000 | Loss 0.6584 | Win count 44
# Epoch 158/5000 | Loss 0.0579 | Win count 44
# Epoch 159/5000 | Loss 0.2370 | Win count 44
# Epoch 160/5000 | Loss 0.2167 | Win count 44
# Epoch 161/5000 | Loss 0.0353 | Win count 44
# Epoch 162/5000 | Loss 0.6584 | Win count 45
# Epoch 163/5000 | Loss 0.3474 | Win count 46
# Epoch 164/5000 | Loss 0.0540 | Win count 46
# Epoch 165/5000 | Loss 0.0231 | Win count 47
# Epoch 166/5000 | Loss 0.0593 | Win count 47
# Epoch 167/5000 | Loss 0.2395 | Win count 47
# Epoch 168/5000 | Loss 0.0239 | Win count 47
# Epoch 169/5000 | Loss 0.0364 | Win count 48
# Epoch 170/5000 | Loss 0.1983 | Win count 49
# Epoch 171/5000 | Loss 0.1617 | Win count 49
# Epoch 172/5000 | Loss 0.3073 | Win count 49
# Epoch 173/5000 | Loss 0.1723 | Win count 49
# Epoch 174/5000 | Loss 0.6842 | Win count 49
# Epoch 175/5000 | Loss 0.1957 | Win count 50
# Epoch 176/5000 | Loss 0.2257 | Win count 50
# Epoch 177/5000 | Loss 0.0556 | Win count 50
# Epoch 178/5000 | Loss 0.0326 | Win count 50
# Epoch 179/5000 | Loss 0.1089 | Win count 50
# Epoch 180/5000 | Loss 0.3869 | Win count 50
# Epoch 181/5000 | Loss 0.0425 | Win count 50
# Epoch 182/5000 | Loss 0.0457 | Win count 50
# Epoch 183/5000 | Loss 0.0529 | Win count 50
# Epoch 184/5000 | Loss 0.2407 | Win count 50
# Epoch 185/5000 | Loss 0.4472 | Win count 50
# Epoch 186/5000 | Loss 0.1007 | Win count 50
# Epoch 187/5000 | Loss 0.8157 | Win count 50
# Epoch 188/5000 | Loss 0.3712 | Win count 50
# Epoch 189/5000 | Loss 0.2262 | Win count 50
# Epoch 190/5000 | Loss 0.0108 | Win count 50
# Epoch 191/5000 | Loss 0.0114 | Win count 50
# Epoch 192/5000 | Loss 0.0207 | Win count 51
# Epoch 193/5000 | Loss 0.1371 | Win count 52
# Epoch 194/5000 | Loss 1.0904 | Win count 53
# Epoch 195/5000 | Loss 0.1732 | Win count 53
# Epoch 196/5000 | Loss 0.2368 | Win count 54
# Epoch 197/5000 | Loss 0.0451 | Win count 54
# Epoch 198/5000 | Loss 0.1785 | Win count 54
# Epoch 199/5000 | Loss 0.0178 | Win count 54
# Epoch 200/5000 | Loss 0.1567 | Win count 54
# Epoch 201/5000 | Loss 0.0636 | Win count 55
# Epoch 202/5000 | Loss 0.0240 | Win count 55
# Epoch 203/5000 | Loss 0.1609 | Win count 55
# Epoch 204/5000 | Loss 0.0199 | Win count 55
# Epoch 205/5000 | Loss 0.1209 | Win count 56
# Epoch 206/5000 | Loss 0.2698 | Win count 56
# Epoch 207/5000 | Loss 0.2122 | Win count 56
# Epoch 208/5000 | Loss 0.3240 | Win count 57
# Epoch 209/5000 | Loss 0.2828 | Win count 57
# Epoch 210/5000 | Loss 0.8912 | Win count 57
# Epoch 211/5000 | Loss 0.2578 | Win count 57
# Epoch 212/5000 | Loss 0.2013 | Win count 57
# Epoch 213/5000 | Loss 0.4863 | Win count 58
# Epoch 214/5000 | Loss 1.0495 | Win count 59
# Epoch 215/5000 | Loss 1.3567 | Win count 59
# Epoch 216/5000 | Loss 0.1906 | Win count 59
# Epoch 217/5000 | Loss 0.2278 | Win count 59
# Epoch 218/5000 | Loss 0.4168 | Win count 60
# Epoch 219/5000 | Loss 0.1151 | Win count 60
# Epoch 220/5000 | Loss 0.0694 | Win count 60
# Epoch 221/5000 | Loss 0.4363 | Win count 60
# Epoch 222/5000 | Loss 0.6766 | Win count 60
# Epoch 223/5000 | Loss 0.6413 | Win count 61
# Epoch 224/5000 | Loss 0.0443 | Win count 62
# Epoch 225/5000 | Loss 0.0977 | Win count 62
# Epoch 226/5000 | Loss 0.8663 | Win count 62
# Epoch 227/5000 | Loss 0.1158 | Win count 62
# Epoch 228/5000 | Loss 0.1951 | Win count 62
# Epoch 229/5000 | Loss 0.3266 | Win count 62
# Epoch 230/5000 | Loss 0.1193 | Win count 62
# Epoch 231/5000 | Loss 0.2039 | Win count 62
# Epoch 232/5000 | Loss 0.9839 | Win count 63
# Epoch 233/5000 | Loss 0.0652 | Win count 64
# Epoch 234/5000 | Loss 0.4266 | Win count 64
# Epoch 235/5000 | Loss 0.0967 | Win count 65
# Epoch 236/5000 | Loss 0.7940 | Win count 66
# Epoch 237/5000 | Loss 0.4552 | Win count 66
# Epoch 238/5000 | Loss 0.4820 | Win count 66
# Epoch 239/5000 | Loss 0.1882 | Win count 67
# Epoch 240/5000 | Loss 0.1913 | Win count 68
# Epoch 241/5000 | Loss 0.1608 | Win count 68
# Epoch 242/5000 | Loss 0.0683 | Win count 69
# Epoch 243/5000 | Loss 0.1984 | Win count 70
# Epoch 244/5000 | Loss 0.6298 | Win count 71
# Epoch 245/5000 | Loss 0.2509 | Win count 71
# Epoch 246/5000 | Loss 0.3534 | Win count 71
# Epoch 247/5000 | Loss 0.0480 | Win count 71
# Epoch 248/5000 | Loss 0.1644 | Win count 72
# Epoch 249/5000 | Loss 0.1909 | Win count 72
# Epoch 250/5000 | Loss 0.2979 | Win count 72
# Epoch 251/5000 | Loss 0.3016 | Win count 72
# Epoch 252/5000 | Loss 0.1875 | Win count 72
# Epoch 253/5000 | Loss 0.0123 | Win count 73
# Epoch 254/5000 | Loss 0.2045 | Win count 73
# Epoch 255/5000 | Loss 0.0423 | Win count 74
# Epoch 256/5000 | Loss 0.0598 | Win count 75
# Epoch 257/5000 | Loss 0.0645 | Win count 76
# Epoch 258/5000 | Loss 0.2346 | Win count 76
# Epoch 259/5000 | Loss 0.0582 | Win count 76
# Epoch 260/5000 | Loss 0.0949 | Win count 76
# Epoch 261/5000 | Loss 0.7689 | Win count 77
# Epoch 262/5000 | Loss 0.2400 | Win count 78
# Epoch 263/5000 | Loss 0.1411 | Win count 78
# Epoch 264/5000 | Loss 0.0359 | Win count 78
# Epoch 265/5000 | Loss 0.4948 | Win count 78
# Epoch 266/5000 | Loss 0.4999 | Win count 78
# Epoch 267/5000 | Loss 0.8425 | Win count 79
# Epoch 268/5000 | Loss 0.1517 | Win count 79
# Epoch 269/5000 | Loss 0.2734 | Win count 80
# Epoch 270/5000 | Loss 0.5810 | Win count 80
# Epoch 271/5000 | Loss 0.1112 | Win count 80
# Epoch 272/5000 | Loss 0.0560 | Win count 80
# Epoch 273/5000 | Loss 0.0425 | Win count 81
# Epoch 274/5000 | Loss 0.0138 | Win count 81
# Epoch 275/5000 | Loss 0.1856 | Win count 82
# Epoch 276/5000 | Loss 0.0287 | Win count 83
# Epoch 277/5000 | Loss 0.0603 | Win count 84
# Epoch 278/5000 | Loss 0.4760 | Win count 84
# Epoch 279/5000 | Loss 0.8926 | Win count 84
# Epoch 280/5000 | Loss 0.1686 | Win count 84
# Epoch 281/5000 | Loss 0.0603 | Win count 84
# Epoch 282/5000 | Loss 0.1564 | Win count 84
# Epoch 283/5000 | Loss 0.0743 | Win count 84
# Epoch 284/5000 | Loss 0.0370 | Win count 84
# Epoch 285/5000 | Loss 0.0420 | Win count 84
# Epoch 286/5000 | Loss 0.6929 | Win count 84
# Epoch 287/5000 | Loss 0.7108 | Win count 85
# Epoch 288/5000 | Loss 0.0398 | Win count 85
# Epoch 289/5000 | Loss 0.8207 | Win count 85
# Epoch 290/5000 | Loss 0.9822 | Win count 85
# Epoch 291/5000 | Loss 0.5421 | Win count 86
# Epoch 292/5000 | Loss 0.2047 | Win count 86
# Epoch 293/5000 | Loss 0.0475 | Win count 86
# Epoch 294/5000 | Loss 0.5309 | Win count 86
# Epoch 295/5000 | Loss 0.4440 | Win count 87
# Epoch 296/5000 | Loss 0.1197 | Win count 87
# Epoch 297/5000 | Loss 0.0641 | Win count 88
# Epoch 298/5000 | Loss 0.2901 | Win count 89
# Epoch 299/5000 | Loss 0.1349 | Win count 89
# Epoch 300/5000 | Loss 0.3113 | Win count 89
# Epoch 301/5000 | Loss 0.0540 | Win count 90
# Epoch 302/5000 | Loss 0.2007 | Win count 90
# Epoch 303/5000 | Loss 0.0315 | Win count 90
# Epoch 304/5000 | Loss 0.2650 | Win count 90
# Epoch 305/5000 | Loss 0.5923 | Win count 90
# Epoch 306/5000 | Loss 0.3313 | Win count 91
# Epoch 307/5000 | Loss 1.6038 | Win count 92
# Epoch 308/5000 | Loss 0.3453 | Win count 92
# Epoch 309/5000 | Loss 0.2852 | Win count 93
# Epoch 310/5000 | Loss 0.0699 | Win count 93
# Epoch 311/5000 | Loss 0.8447 | Win count 93
# Epoch 312/5000 | Loss 0.1700 | Win count 93
# Epoch 313/5000 | Loss 0.0971 | Win count 93
# Epoch 314/5000 | Loss 0.4916 | Win count 94
# Epoch 315/5000 | Loss 0.1025 | Win count 94
# Epoch 316/5000 | Loss 0.0358 | Win count 94
# Epoch 317/5000 | Loss 0.0141 | Win count 94
# Epoch 318/5000 | Loss 0.0734 | Win count 94
# Epoch 319/5000 | Loss 0.0676 | Win count 94
# Epoch 320/5000 | Loss 0.1557 | Win count 94
# Epoch 321/5000 | Loss 0.0226 | Win count 94
# Epoch 322/5000 | Loss 0.0400 | Win count 95
# Epoch 323/5000 | Loss 0.2836 | Win count 95
# Epoch 324/5000 | Loss 0.0170 | Win count 96
# Epoch 325/5000 | Loss 0.3574 | Win count 97
# Epoch 326/5000 | Loss 0.6337 | Win count 97
# Epoch 327/5000 | Loss 0.2194 | Win count 97
# Epoch 328/5000 | Loss 0.1690 | Win count 97
# Epoch 329/5000 | Loss 0.6206 | Win count 98
# Epoch 330/5000 | Loss 0.1204 | Win count 99
# Epoch 331/5000 | Loss 0.0530 | Win count 100
# Epoch 332/5000 | Loss 0.0572 | Win count 100
# Epoch 333/5000 | Loss 0.1548 | Win count 101
# Epoch 334/5000 | Loss 0.0575 | Win count 102
# Epoch 335/5000 | Loss 0.0566 | Win count 102
# Epoch 336/5000 | Loss 0.0579 | Win count 102
# Epoch 337/5000 | Loss 0.0949 | Win count 102
# Epoch 338/5000 | Loss 0.1645 | Win count 103
# Epoch 339/5000 | Loss 0.0197 | Win count 104
# Epoch 340/5000 | Loss 0.1080 | Win count 105
# Epoch 341/5000 | Loss 0.6577 | Win count 105
# Epoch 342/5000 | Loss 0.2919 | Win count 106
# Epoch 343/5000 | Loss 0.1466 | Win count 106
# Epoch 344/5000 | Loss 0.2729 | Win count 106
# Epoch 345/5000 | Loss 0.1094 | Win count 106
# Epoch 346/5000 | Loss 0.0361 | Win count 106
# Epoch 347/5000 | Loss 0.2799 | Win count 106
# Epoch 348/5000 | Loss 0.0911 | Win count 107
# Epoch 349/5000 | Loss 0.6040 | Win count 107
# Epoch 350/5000 | Loss 0.1503 | Win count 108
# Epoch 351/5000 | Loss 0.1780 | Win count 108
# Epoch 352/5000 | Loss 0.1243 | Win count 108
# Epoch 353/5000 | Loss 0.0960 | Win count 109
# Epoch 354/5000 | Loss 0.0554 | Win count 110
# Epoch 355/5000 | Loss 0.4794 | Win count 110
# Epoch 356/5000 | Loss 0.1538 | Win count 111
# Epoch 357/5000 | Loss 0.0822 | Win count 111
# Epoch 358/5000 | Loss 0.6422 | Win count 112
# Epoch 359/5000 | Loss 0.1455 | Win count 112
# Epoch 360/5000 | Loss 0.2292 | Win count 112
# Epoch 361/5000 | Loss 0.1522 | Win count 113
# Epoch 362/5000 | Loss 0.3431 | Win count 114
# Epoch 363/5000 | Loss 0.1439 | Win count 114
# Epoch 364/5000 | Loss 0.0632 | Win count 115
# Epoch 365/5000 | Loss 0.6555 | Win count 116
# Epoch 366/5000 | Loss 0.2142 | Win count 117
# Epoch 367/5000 | Loss 0.0836 | Win count 118
# Epoch 368/5000 | Loss 0.0515 | Win count 118
# Epoch 369/5000 | Loss 0.1160 | Win count 118
# Epoch 370/5000 | Loss 0.5275 | Win count 118
# Epoch 371/5000 | Loss 0.2753 | Win count 119
# Epoch 372/5000 | Loss 0.1928 | Win count 119
# Epoch 373/5000 | Loss 0.1357 | Win count 119
# Epoch 374/5000 | Loss 0.3673 | Win count 120
# Epoch 375/5000 | Loss 0.0777 | Win count 121
# Epoch 376/5000 | Loss 0.1128 | Win count 122
# Epoch 377/5000 | Loss 0.0723 | Win count 123
# Epoch 378/5000 | Loss 0.1612 | Win count 123
# Epoch 379/5000 | Loss 0.0187 | Win count 124
# Epoch 380/5000 | Loss 0.4809 | Win count 125
# Epoch 381/5000 | Loss 0.0812 | Win count 126
# Epoch 382/5000 | Loss 0.3351 | Win count 127
# Epoch 383/5000 | Loss 0.2412 | Win count 127
# Epoch 384/5000 | Loss 0.0359 | Win count 127
# Epoch 385/5000 | Loss 0.1274 | Win count 128
# Epoch 386/5000 | Loss 0.0563 | Win count 128
# Epoch 387/5000 | Loss 0.0505 | Win count 128
# Epoch 388/5000 | Loss 0.1207 | Win count 128
# Epoch 389/5000 | Loss 0.4629 | Win count 129
# Epoch 390/5000 | Loss 0.7411 | Win count 130
# Epoch 391/5000 | Loss 0.0395 | Win count 131
# Epoch 392/5000 | Loss 0.1601 | Win count 131
# Epoch 393/5000 | Loss 0.1159 | Win count 132
# Epoch 394/5000 | Loss 0.0328 | Win count 133
# Epoch 395/5000 | Loss 0.6938 | Win count 133
# Epoch 396/5000 | Loss 0.0820 | Win count 133
# Epoch 397/5000 | Loss 0.2025 | Win count 134
# Epoch 398/5000 | Loss 0.0552 | Win count 134
# Epoch 399/5000 | Loss 0.1081 | Win count 135
# Epoch 400/5000 | Loss 0.1014 | Win count 136
# Epoch 401/5000 | Loss 0.2731 | Win count 137
# Epoch 402/5000 | Loss 0.2406 | Win count 137
# Epoch 403/5000 | Loss 0.7086 | Win count 137
# Epoch 404/5000 | Loss 0.0661 | Win count 137
# Epoch 405/5000 | Loss 0.3669 | Win count 138
# Epoch 406/5000 | Loss 0.2930 | Win count 138
# Epoch 407/5000 | Loss 0.1753 | Win count 138
# Epoch 408/5000 | Loss 0.7640 | Win count 139
# Epoch 409/5000 | Loss 0.1471 | Win count 140
# Epoch 410/5000 | Loss 0.0839 | Win count 140
# Epoch 411/5000 | Loss 0.2593 | Win count 140
# Epoch 412/5000 | Loss 0.0973 | Win count 141
# Epoch 413/5000 | Loss 0.1816 | Win count 142
# Epoch 414/5000 | Loss 0.0843 | Win count 142
# Epoch 415/5000 | Loss 0.0809 | Win count 143
# Epoch 416/5000 | Loss 0.0290 | Win count 143
# Epoch 417/5000 | Loss 0.2758 | Win count 143
# Epoch 418/5000 | Loss 0.3637 | Win count 144
# Epoch 419/5000 | Loss 0.2836 | Win count 145
# Epoch 420/5000 | Loss 0.3586 | Win count 145
# Epoch 421/5000 | Loss 0.0691 | Win count 146
# Epoch 422/5000 | Loss 0.1590 | Win count 147
# Epoch 423/5000 | Loss 0.0792 | Win count 148
# Epoch 424/5000 | Loss 0.1028 | Win count 149
# Epoch 425/5000 | Loss 0.0773 | Win count 150
# Epoch 426/5000 | Loss 0.0342 | Win count 150
# Epoch 427/5000 | Loss 0.0469 | Win count 150
# Epoch 428/5000 | Loss 0.2131 | Win count 151
# Epoch 429/5000 | Loss 0.0823 | Win count 152
# Epoch 430/5000 | Loss 0.5157 | Win count 152
# Epoch 431/5000 | Loss 0.1043 | Win count 153
# Epoch 432/5000 | Loss 0.0530 | Win count 153
# Epoch 433/5000 | Loss 0.1326 | Win count 154
# Epoch 434/5000 | Loss 0.0380 | Win count 155
# Epoch 435/5000 | Loss 0.4073 | Win count 155
# Epoch 436/5000 | Loss 0.0419 | Win count 156
# Epoch 437/5000 | Loss 2.0451 | Win count 157
# Epoch 438/5000 | Loss 0.0810 | Win count 158
# Epoch 439/5000 | Loss 0.0228 | Win count 159
# Epoch 440/5000 | Loss 0.1866 | Win count 160
# Epoch 441/5000 | Loss 0.0402 | Win count 161
# Epoch 442/5000 | Loss 0.0506 | Win count 162
# Epoch 443/5000 | Loss 0.1064 | Win count 163
# Epoch 444/5000 | Loss 0.0190 | Win count 164
# Epoch 445/5000 | Loss 0.3830 | Win count 165
# Epoch 446/5000 | Loss 0.3848 | Win count 165
# Epoch 447/5000 | Loss 0.1540 | Win count 165
# Epoch 448/5000 | Loss 0.1298 | Win count 165
# Epoch 449/5000 | Loss 0.8582 | Win count 165
# Epoch 450/5000 | Loss 0.1567 | Win count 165
# Epoch 451/5000 | Loss 0.0826 | Win count 166
# Epoch 452/5000 | Loss 0.0663 | Win count 166
# Epoch 453/5000 | Loss 0.4348 | Win count 167
# Epoch 454/5000 | Loss 0.0914 | Win count 167
# Epoch 455/5000 | Loss 1.4145 | Win count 167
# Epoch 456/5000 | Loss 0.3131 | Win count 167
# Epoch 457/5000 | Loss 0.1416 | Win count 167
# Epoch 458/5000 | Loss 0.3035 | Win count 168
# Epoch 459/5000 | Loss 0.0260 | Win count 168
# Epoch 460/5000 | Loss 0.0909 | Win count 169
# Epoch 461/5000 | Loss 0.0756 | Win count 169
# Epoch 462/5000 | Loss 0.5005 | Win count 170
# Epoch 463/5000 | Loss 0.1324 | Win count 170
# Epoch 464/5000 | Loss 0.1971 | Win count 170
# Epoch 465/5000 | Loss 1.1772 | Win count 170
# Epoch 466/5000 | Loss 0.4478 | Win count 170
# Epoch 467/5000 | Loss 0.2823 | Win count 170
# Epoch 468/5000 | Loss 0.2185 | Win count 171
# Epoch 469/5000 | Loss 0.3432 | Win count 171
# Epoch 470/5000 | Loss 0.1262 | Win count 171
# Epoch 471/5000 | Loss 0.0870 | Win count 171
# Epoch 472/5000 | Loss 0.0762 | Win count 171
# Epoch 473/5000 | Loss 0.5974 | Win count 172
# Epoch 474/5000 | Loss 0.1854 | Win count 173
# Epoch 475/5000 | Loss 0.2640 | Win count 174
# Epoch 476/5000 | Loss 0.6515 | Win count 175
# Epoch 477/5000 | Loss 0.1915 | Win count 176
# Epoch 478/5000 | Loss 0.4010 | Win count 177
# Epoch 479/5000 | Loss 0.0386 | Win count 177
# Epoch 480/5000 | Loss 0.0846 | Win count 177
# Epoch 481/5000 | Loss 1.1739 | Win count 177
# Epoch 482/5000 | Loss 0.6059 | Win count 177
# Epoch 483/5000 | Loss 0.7625 | Win count 177
# Epoch 484/5000 | Loss 0.0968 | Win count 177
# Epoch 485/5000 | Loss 0.2276 | Win count 177
# Epoch 486/5000 | Loss 0.2790 | Win count 177
# Epoch 487/5000 | Loss 0.3455 | Win count 178
# Epoch 488/5000 | Loss 0.8169 | Win count 178
# Epoch 489/5000 | Loss 0.8271 | Win count 178
# Epoch 490/5000 | Loss 0.0756 | Win count 178
# Epoch 491/5000 | Loss 0.1046 | Win count 178
# Epoch 492/5000 | Loss 0.1780 | Win count 178
# Epoch 493/5000 | Loss 0.3305 | Win count 179
# Epoch 494/5000 | Loss 0.2331 | Win count 180
# Epoch 495/5000 | Loss 0.0856 | Win count 181
# Epoch 496/5000 | Loss 0.1421 | Win count 182
# Epoch 497/5000 | Loss 0.2466 | Win count 182
# Epoch 498/5000 | Loss 0.2240 | Win count 182
# Epoch 499/5000 | Loss 0.1457 | Win count 182
# Epoch 500/5000 | Loss 0.1747 | Win count 183
# Epoch 501/5000 | Loss 0.0859 | Win count 184
# Epoch 502/5000 | Loss 0.0906 | Win count 184
# Epoch 503/5000 | Loss 0.0554 | Win count 185
# Epoch 504/5000 | Loss 0.0132 | Win count 185
# Epoch 505/5000 | Loss 0.1038 | Win count 186
# Epoch 506/5000 | Loss 0.1186 | Win count 187
# Epoch 507/5000 | Loss 0.0480 | Win count 187
# Epoch 508/5000 | Loss 0.0586 | Win count 188
# Epoch 509/5000 | Loss 0.2625 | Win count 189
# Epoch 510/5000 | Loss 0.0213 | Win count 190
# Epoch 511/5000 | Loss 0.0512 | Win count 190
# Epoch 512/5000 | Loss 0.1592 | Win count 190
# Epoch 513/5000 | Loss 0.0754 | Win count 190
# Epoch 514/5000 | Loss 0.4420 | Win count 191
# Epoch 515/5000 | Loss 0.0314 | Win count 191
# Epoch 516/5000 | Loss 0.1212 | Win count 192
# Epoch 517/5000 | Loss 0.0309 | Win count 193
# Epoch 518/5000 | Loss 0.0399 | Win count 194
# Epoch 519/5000 | Loss 0.1139 | Win count 195
# Epoch 520/5000 | Loss 0.0742 | Win count 196
# Epoch 521/5000 | Loss 0.1042 | Win count 196
# Epoch 522/5000 | Loss 0.3819 | Win count 196
# Epoch 523/5000 | Loss 0.2031 | Win count 196
# Epoch 524/5000 | Loss 0.0489 | Win count 196
# Epoch 525/5000 | Loss 0.3424 | Win count 197
# Epoch 526/5000 | Loss 0.1150 | Win count 198
# Epoch 527/5000 | Loss 0.0339 | Win count 199
# Epoch 528/5000 | Loss 0.0992 | Win count 199
# Epoch 529/5000 | Loss 0.1378 | Win count 200
# Epoch 530/5000 | Loss 0.5901 | Win count 201
# Epoch 531/5000 | Loss 0.1408 | Win count 202
# Epoch 532/5000 | Loss 0.1003 | Win count 202
# Epoch 533/5000 | Loss 0.1284 | Win count 202
# Epoch 534/5000 | Loss 0.0852 | Win count 203
# Epoch 535/5000 | Loss 0.0452 | Win count 204
# Epoch 536/5000 | Loss 0.6364 | Win count 205
# Epoch 537/5000 | Loss 0.0898 | Win count 205
# Epoch 538/5000 | Loss 0.0597 | Win count 206
# Epoch 539/5000 | Loss 0.0342 | Win count 206
# Epoch 540/5000 | Loss 0.1933 | Win count 207
# Epoch 541/5000 | Loss 0.2130 | Win count 208
# Epoch 542/5000 | Loss 0.1251 | Win count 209
# Epoch 543/5000 | Loss 0.1235 | Win count 210
# Epoch 544/5000 | Loss 0.0962 | Win count 211
# Epoch 545/5000 | Loss 0.0846 | Win count 212
# Epoch 546/5000 | Loss 0.0819 | Win count 213
# Epoch 547/5000 | Loss 0.2092 | Win count 214
# Epoch 548/5000 | Loss 0.2847 | Win count 215
# Epoch 549/5000 | Loss 0.0680 | Win count 215
# Epoch 550/5000 | Loss 0.1174 | Win count 216
# Epoch 551/5000 | Loss 0.0508 | Win count 216
# Epoch 552/5000 | Loss 0.1635 | Win count 216
# Epoch 553/5000 | Loss 0.1554 | Win count 217
# Epoch 554/5000 | Loss 1.2253 | Win count 217
# Epoch 555/5000 | Loss 0.1574 | Win count 217
# Epoch 556/5000 | Loss 0.1955 | Win count 217
# Epoch 557/5000 | Loss 0.0464 | Win count 218
# Epoch 558/5000 | Loss 0.1635 | Win count 218
# Epoch 559/5000 | Loss 0.1569 | Win count 218
# Epoch 560/5000 | Loss 1.2448 | Win count 219
# Epoch 561/5000 | Loss 0.0394 | Win count 219
# Epoch 562/5000 | Loss 0.2685 | Win count 220
# Epoch 563/5000 | Loss 0.0948 | Win count 220
# Epoch 564/5000 | Loss 0.0557 | Win count 220
# Epoch 565/5000 | Loss 0.2188 | Win count 221
# Epoch 566/5000 | Loss 0.0396 | Win count 221
# Epoch 567/5000 | Loss 0.0376 | Win count 221
# Epoch 568/5000 | Loss 0.1171 | Win count 222
# Epoch 569/5000 | Loss 0.3137 | Win count 223
# Epoch 570/5000 | Loss 0.3582 | Win count 223
# Epoch 571/5000 | Loss 0.1359 | Win count 223
# Epoch 572/5000 | Loss 0.1022 | Win count 224
# Epoch 573/5000 | Loss 0.0375 | Win count 225
# Epoch 574/5000 | Loss 0.0430 | Win count 225
# Epoch 575/5000 | Loss 0.2242 | Win count 226
# Epoch 576/5000 | Loss 0.3266 | Win count 226
# Epoch 577/5000 | Loss 0.0925 | Win count 226
# Epoch 578/5000 | Loss 0.0788 | Win count 227
# Epoch 579/5000 | Loss 0.1239 | Win count 228
# Epoch 580/5000 | Loss 0.0722 | Win count 228
# Epoch 581/5000 | Loss 0.3615 | Win count 228
# Epoch 582/5000 | Loss 1.1628 | Win count 228
# Epoch 583/5000 | Loss 0.6472 | Win count 229
# Epoch 584/5000 | Loss 0.0563 | Win count 229
# Epoch 585/5000 | Loss 0.0618 | Win count 230
# Epoch 586/5000 | Loss 0.1829 | Win count 231
# Epoch 587/5000 | Loss 0.1079 | Win count 231
# Epoch 588/5000 | Loss 0.0441 | Win count 231
# Epoch 589/5000 | Loss 0.9199 | Win count 231
# Epoch 590/5000 | Loss 0.9399 | Win count 232
# Epoch 591/5000 | Loss 0.2005 | Win count 233
# Epoch 592/5000 | Loss 0.0643 | Win count 233
# Epoch 593/5000 | Loss 0.0944 | Win count 233
# Epoch 594/5000 | Loss 0.8571 | Win count 233
# Epoch 595/5000 | Loss 0.7890 | Win count 234
# Epoch 596/5000 | Loss 1.0447 | Win count 235
# Epoch 597/5000 | Loss 0.2683 | Win count 236
# Epoch 598/5000 | Loss 0.0615 | Win count 237
# Epoch 599/5000 | Loss 0.2162 | Win count 238
# Epoch 600/5000 | Loss 0.6301 | Win count 239
# Epoch 601/5000 | Loss 0.0709 | Win count 239
# Epoch 602/5000 | Loss 0.0437 | Win count 240
# Epoch 603/5000 | Loss 0.7908 | Win count 241
# Epoch 604/5000 | Loss 0.1046 | Win count 242
# Epoch 605/5000 | Loss 0.0568 | Win count 243
# Epoch 606/5000 | Loss 0.8461 | Win count 243
# Epoch 607/5000 | Loss 0.1510 | Win count 244
# Epoch 608/5000 | Loss 0.2327 | Win count 244
# Epoch 609/5000 | Loss 0.0900 | Win count 244
# Epoch 610/5000 | Loss 0.1142 | Win count 245
# Epoch 611/5000 | Loss 0.5970 | Win count 246
# Epoch 612/5000 | Loss 0.2278 | Win count 247
# Epoch 613/5000 | Loss 0.0671 | Win count 248
# Epoch 614/5000 | Loss 0.1830 | Win count 248
# Epoch 615/5000 | Loss 0.0239 | Win count 249
# Epoch 616/5000 | Loss 0.0831 | Win count 249
# Epoch 617/5000 | Loss 0.2911 | Win count 249
# Epoch 618/5000 | Loss 0.1707 | Win count 250
# Epoch 619/5000 | Loss 1.4818 | Win count 250
# Epoch 620/5000 | Loss 0.3683 | Win count 250
# Epoch 621/5000 | Loss 0.0786 | Win count 250
# Epoch 622/5000 | Loss 0.2027 | Win count 251
# Epoch 623/5000 | Loss 0.0309 | Win count 252
# Epoch 624/5000 | Loss 0.2076 | Win count 252
# Epoch 625/5000 | Loss 0.2066 | Win count 253
# Epoch 626/5000 | Loss 0.0411 | Win count 254
# Epoch 627/5000 | Loss 0.3577 | Win count 255
# Epoch 628/5000 | Loss 0.0483 | Win count 256
# Epoch 629/5000 | Loss 0.2274 | Win count 257
# Epoch 630/5000 | Loss 0.2306 | Win count 258
# Epoch 631/5000 | Loss 0.3100 | Win count 258
# Epoch 632/5000 | Loss 0.0509 | Win count 259
# Epoch 633/5000 | Loss 0.0704 | Win count 260
# Epoch 634/5000 | Loss 0.1241 | Win count 261
# Epoch 635/5000 | Loss 0.2979 | Win count 262
# Epoch 636/5000 | Loss 0.4596 | Win count 263
# Epoch 637/5000 | Loss 0.0479 | Win count 263
# Epoch 638/5000 | Loss 0.0205 | Win count 263
# Epoch 639/5000 | Loss 0.1923 | Win count 264
# Epoch 640/5000 | Loss 0.0527 | Win count 264
# Epoch 641/5000 | Loss 0.0211 | Win count 264
# Epoch 642/5000 | Loss 0.9097 | Win count 265
# Epoch 643/5000 | Loss 0.2405 | Win count 265
# Epoch 644/5000 | Loss 0.3653 | Win count 266
# Epoch 645/5000 | Loss 0.4686 | Win count 267
# Epoch 646/5000 | Loss 0.0388 | Win count 267
# Epoch 647/5000 | Loss 0.6599 | Win count 268
# Epoch 648/5000 | Loss 0.1847 | Win count 268
# Epoch 649/5000 | Loss 0.0495 | Win count 269
# Epoch 650/5000 | Loss 0.0378 | Win count 270
# Epoch 651/5000 | Loss 0.2287 | Win count 270
# Epoch 652/5000 | Loss 0.0472 | Win count 270
# Epoch 653/5000 | Loss 0.3957 | Win count 271
# Epoch 654/5000 | Loss 0.0968 | Win count 271
# Epoch 655/5000 | Loss 0.2633 | Win count 272
# Epoch 656/5000 | Loss 0.0225 | Win count 273
# Epoch 657/5000 | Loss 0.2308 | Win count 273
# Epoch 658/5000 | Loss 0.1299 | Win count 273
# Epoch 659/5000 | Loss 0.0427 | Win count 273
# Epoch 660/5000 | Loss 0.8998 | Win count 273
# Epoch 661/5000 | Loss 0.0644 | Win count 274
# Epoch 662/5000 | Loss 0.1860 | Win count 275
# Epoch 663/5000 | Loss 0.0915 | Win count 275
# Epoch 664/5000 | Loss 0.1606 | Win count 276
# Epoch 665/5000 | Loss 0.1845 | Win count 277
# Epoch 666/5000 | Loss 0.0292 | Win count 277
# Epoch 667/5000 | Loss 0.1255 | Win count 278
# Epoch 668/5000 | Loss 0.4459 | Win count 279
# Epoch 669/5000 | Loss 1.2007 | Win count 280
# Epoch 670/5000 | Loss 0.5063 | Win count 280
# Epoch 671/5000 | Loss 0.1448 | Win count 281
# Epoch 672/5000 | Loss 0.0689 | Win count 281
# Epoch 673/5000 | Loss 0.0943 | Win count 281
# Epoch 674/5000 | Loss 0.0158 | Win count 282
# Epoch 675/5000 | Loss 0.7660 | Win count 283
# Epoch 676/5000 | Loss 0.0346 | Win count 284
# Epoch 677/5000 | Loss 0.6747 | Win count 285
# Epoch 678/5000 | Loss 0.0797 | Win count 286
# Epoch 679/5000 | Loss 0.3964 | Win count 286
# Epoch 680/5000 | Loss 0.5895 | Win count 287
# Epoch 681/5000 | Loss 0.0566 | Win count 287
# Epoch 682/5000 | Loss 0.0347 | Win count 288
# Epoch 683/5000 | Loss 0.2427 | Win count 289
# Epoch 684/5000 | Loss 0.4069 | Win count 289
# Epoch 685/5000 | Loss 0.2305 | Win count 290
# Epoch 686/5000 | Loss 0.0699 | Win count 291
# Epoch 687/5000 | Loss 0.1117 | Win count 291
# Epoch 688/5000 | Loss 0.0668 | Win count 291
# Epoch 689/5000 | Loss 0.1069 | Win count 291
# Epoch 690/5000 | Loss 0.0845 | Win count 292
# Epoch 691/5000 | Loss 0.0472 | Win count 293
# Epoch 692/5000 | Loss 0.0337 | Win count 294
# Epoch 693/5000 | Loss 0.6746 | Win count 294
# Epoch 694/5000 | Loss 0.0835 | Win count 294
# Epoch 695/5000 | Loss 0.8285 | Win count 294
# Epoch 696/5000 | Loss 0.4012 | Win count 295
# Epoch 697/5000 | Loss 0.5393 | Win count 296
# Epoch 698/5000 | Loss 0.0638 | Win count 297
# Epoch 699/5000 | Loss 0.2135 | Win count 298
# Epoch 700/5000 | Loss 0.0386 | Win count 299
# Epoch 701/5000 | Loss 0.2717 | Win count 300
# Epoch 702/5000 | Loss 0.0273 | Win count 301
# Epoch 703/5000 | Loss 0.3201 | Win count 301
# Epoch 704/5000 | Loss 0.1896 | Win count 302
# Epoch 705/5000 | Loss 0.8982 | Win count 303
# Epoch 706/5000 | Loss 0.0337 | Win count 304
# Epoch 707/5000 | Loss 0.0405 | Win count 304
# Epoch 708/5000 | Loss 0.5450 | Win count 305
# Epoch 709/5000 | Loss 0.0803 | Win count 306
# Epoch 710/5000 | Loss 0.3499 | Win count 307
# Epoch 711/5000 | Loss 0.4099 | Win count 308
# Epoch 712/5000 | Loss 0.0727 | Win count 309
# Epoch 713/5000 | Loss 0.0523 | Win count 310
# Epoch 714/5000 | Loss 0.2293 | Win count 311
# Epoch 715/5000 | Loss 0.0841 | Win count 312
# Epoch 716/5000 | Loss 0.6280 | Win count 313
# Epoch 717/5000 | Loss 0.1785 | Win count 314
# Epoch 718/5000 | Loss 0.0703 | Win count 314
# Epoch 719/5000 | Loss 0.0566 | Win count 314
# Epoch 720/5000 | Loss 0.1317 | Win count 314
# Epoch 721/5000 | Loss 0.5070 | Win count 314
# Epoch 722/5000 | Loss 0.1562 | Win count 315
# Epoch 723/5000 | Loss 0.0281 | Win count 316
# Epoch 724/5000 | Loss 0.0760 | Win count 317
# Epoch 725/5000 | Loss 0.0555 | Win count 318
# Epoch 726/5000 | Loss 0.4743 | Win count 319
# Epoch 727/5000 | Loss 0.3609 | Win count 320
# Epoch 728/5000 | Loss 0.2691 | Win count 320
# Epoch 729/5000 | Loss 0.3628 | Win count 320
# Epoch 730/5000 | Loss 0.0283 | Win count 320
# Epoch 731/5000 | Loss 0.1115 | Win count 321
# Epoch 732/5000 | Loss 0.1072 | Win count 322
# Epoch 733/5000 | Loss 0.1097 | Win count 322
# Epoch 734/5000 | Loss 0.3061 | Win count 322
# Epoch 735/5000 | Loss 0.1019 | Win count 323
# Epoch 736/5000 | Loss 0.1102 | Win count 324
# Epoch 737/5000 | Loss 0.1075 | Win count 325
# Epoch 738/5000 | Loss 0.5189 | Win count 325
# Epoch 739/5000 | Loss 0.1316 | Win count 325
# Epoch 740/5000 | Loss 0.0199 | Win count 326
# Epoch 741/5000 | Loss 0.1480 | Win count 326
# Epoch 742/5000 | Loss 0.0579 | Win count 326
# Epoch 743/5000 | Loss 0.0253 | Win count 326
# Epoch 744/5000 | Loss 0.0114 | Win count 327
# Epoch 745/5000 | Loss 0.0476 | Win count 327
# Epoch 746/5000 | Loss 0.6562 | Win count 327
# Epoch 747/5000 | Loss 0.0657 | Win count 327
# Epoch 748/5000 | Loss 0.0785 | Win count 328
# Epoch 749/5000 | Loss 0.0464 | Win count 328
# Epoch 750/5000 | Loss 0.0181 | Win count 329
# Epoch 751/5000 | Loss 0.9697 | Win count 329
# Epoch 752/5000 | Loss 0.1838 | Win count 330
# Epoch 753/5000 | Loss 0.3925 | Win count 330
# Epoch 754/5000 | Loss 0.6048 | Win count 330
# Epoch 755/5000 | Loss 0.0903 | Win count 331
# Epoch 756/5000 | Loss 0.1921 | Win count 332
# Epoch 757/5000 | Loss 0.6078 | Win count 332
# Epoch 758/5000 | Loss 0.0719 | Win count 332
# Epoch 759/5000 | Loss 0.2262 | Win count 332
# Epoch 760/5000 | Loss 0.1303 | Win count 333
# Epoch 761/5000 | Loss 0.6629 | Win count 333
# Epoch 762/5000 | Loss 0.1853 | Win count 333
# Epoch 763/5000 | Loss 0.1955 | Win count 334
# Epoch 764/5000 | Loss 0.0543 | Win count 335
# Epoch 765/5000 | Loss 0.1579 | Win count 335
# Epoch 766/5000 | Loss 0.0333 | Win count 336
# Epoch 767/5000 | Loss 0.0962 | Win count 336
# Epoch 768/5000 | Loss 0.0218 | Win count 336
# Epoch 769/5000 | Loss 0.0772 | Win count 336
# Epoch 770/5000 | Loss 0.2065 | Win count 336
# Epoch 771/5000 | Loss 0.0400 | Win count 336
# Epoch 772/5000 | Loss 0.0744 | Win count 337
# Epoch 773/5000 | Loss 0.2340 | Win count 338
# Epoch 774/5000 | Loss 0.0944 | Win count 338
# Epoch 775/5000 | Loss 0.2260 | Win count 339
# Epoch 776/5000 | Loss 0.2217 | Win count 339
# Epoch 777/5000 | Loss 0.0895 | Win count 339
# Epoch 778/5000 | Loss 0.0160 | Win count 339
# Epoch 779/5000 | Loss 0.0743 | Win count 339
# Epoch 780/5000 | Loss 0.0356 | Win count 340
# Epoch 781/5000 | Loss 0.2025 | Win count 340
# Epoch 782/5000 | Loss 0.1081 | Win count 341
# Epoch 783/5000 | Loss 0.3347 | Win count 341
# Epoch 784/5000 | Loss 0.1363 | Win count 341
# Epoch 785/5000 | Loss 0.4519 | Win count 341
# Epoch 786/5000 | Loss 0.0425 | Win count 342
# Epoch 787/5000 | Loss 0.1298 | Win count 342
# Epoch 788/5000 | Loss 0.0620 | Win count 343
# Epoch 789/5000 | Loss 0.1267 | Win count 344
# Epoch 790/5000 | Loss 0.1030 | Win count 345
# Epoch 791/5000 | Loss 0.6380 | Win count 345
# Epoch 792/5000 | Loss 0.1673 | Win count 345
# Epoch 793/5000 | Loss 0.0737 | Win count 346
# Epoch 794/5000 | Loss 0.0421 | Win count 347
# Epoch 795/5000 | Loss 0.0340 | Win count 347
# Epoch 796/5000 | Loss 0.0197 | Win count 348
# Epoch 797/5000 | Loss 0.0541 | Win count 349
# Epoch 798/5000 | Loss 0.0406 | Win count 349
# Epoch 799/5000 | Loss 0.0553 | Win count 350
# Epoch 800/5000 | Loss 0.4309 | Win count 351
# Epoch 801/5000 | Loss 0.9707 | Win count 351
# Epoch 802/5000 | Loss 0.0387 | Win count 351
# Epoch 803/5000 | Loss 0.2606 | Win count 351
# Epoch 804/5000 | Loss 0.3195 | Win count 352
# Epoch 805/5000 | Loss 0.3574 | Win count 352
# Epoch 806/5000 | Loss 0.0778 | Win count 353
# Epoch 807/5000 | Loss 0.2110 | Win count 354
# Epoch 808/5000 | Loss 0.2150 | Win count 355
# Epoch 809/5000 | Loss 0.0456 | Win count 356
# Epoch 810/5000 | Loss 0.1103 | Win count 356
# Epoch 811/5000 | Loss 0.5707 | Win count 356
# Epoch 812/5000 | Loss 0.0285 | Win count 357
# Epoch 813/5000 | Loss 0.4655 | Win count 358
# Epoch 814/5000 | Loss 0.1620 | Win count 358
# Epoch 815/5000 | Loss 0.0721 | Win count 359
# Epoch 816/5000 | Loss 0.7587 | Win count 359
# Epoch 817/5000 | Loss 0.0190 | Win count 359
# Epoch 818/5000 | Loss 0.3000 | Win count 360
# Epoch 819/5000 | Loss 0.1889 | Win count 361
# Epoch 820/5000 | Loss 0.2050 | Win count 362
# Epoch 821/5000 | Loss 0.1508 | Win count 363
# Epoch 822/5000 | Loss 0.6823 | Win count 364
# Epoch 823/5000 | Loss 0.2939 | Win count 364
# Epoch 824/5000 | Loss 0.0821 | Win count 364
# Epoch 825/5000 | Loss 0.2990 | Win count 364
# Epoch 826/5000 | Loss 0.0618 | Win count 365
# Epoch 827/5000 | Loss 0.2649 | Win count 366
# Epoch 828/5000 | Loss 0.2221 | Win count 366
# Epoch 829/5000 | Loss 0.0800 | Win count 366
# Epoch 830/5000 | Loss 0.2735 | Win count 367
# Epoch 831/5000 | Loss 0.4650 | Win count 367
# Epoch 832/5000 | Loss 0.4116 | Win count 367
# Epoch 833/5000 | Loss 0.2811 | Win count 368
# Epoch 834/5000 | Loss 0.0804 | Win count 368
# Epoch 835/5000 | Loss 0.0299 | Win count 369
# Epoch 836/5000 | Loss 0.3121 | Win count 370
# Epoch 837/5000 | Loss 0.4355 | Win count 371
# Epoch 838/5000 | Loss 0.2754 | Win count 372
# Epoch 839/5000 | Loss 0.0796 | Win count 372
# Epoch 840/5000 | Loss 0.1084 | Win count 373
# Epoch 841/5000 | Loss 0.3162 | Win count 373
# Epoch 842/5000 | Loss 0.6029 | Win count 374
# Epoch 843/5000 | Loss 0.0739 | Win count 374
# Epoch 844/5000 | Loss 0.1964 | Win count 374
# Epoch 845/5000 | Loss 0.0339 | Win count 375
# Epoch 846/5000 | Loss 1.3286 | Win count 376
# Epoch 847/5000 | Loss 0.8699 | Win count 377
# Epoch 848/5000 | Loss 0.1135 | Win count 378
# Epoch 849/5000 | Loss 0.1184 | Win count 379
# Epoch 850/5000 | Loss 0.1678 | Win count 380
# Epoch 851/5000 | Loss 0.2359 | Win count 381
# Epoch 852/5000 | Loss 0.2232 | Win count 382
# Epoch 853/5000 | Loss 0.0483 | Win count 383
# Epoch 854/5000 | Loss 0.0532 | Win count 383
# Epoch 855/5000 | Loss 0.2161 | Win count 383
# Epoch 856/5000 | Loss 0.4093 | Win count 384
# Epoch 857/5000 | Loss 0.0562 | Win count 385
# Epoch 858/5000 | Loss 0.1899 | Win count 385
# Epoch 859/5000 | Loss 0.0577 | Win count 386
# Epoch 860/5000 | Loss 0.0583 | Win count 386
# Epoch 861/5000 | Loss 0.0418 | Win count 387
# Epoch 862/5000 | Loss 1.2948 | Win count 388
# Epoch 863/5000 | Loss 0.3349 | Win count 388
# Epoch 864/5000 | Loss 0.0259 | Win count 389
# Epoch 865/5000 | Loss 0.1866 | Win count 390
# Epoch 866/5000 | Loss 0.1286 | Win count 390
# Epoch 867/5000 | Loss 0.0253 | Win count 391
# Epoch 868/5000 | Loss 0.8266 | Win count 392
# Epoch 869/5000 | Loss 0.4345 | Win count 393
# Epoch 870/5000 | Loss 0.1231 | Win count 393
# Epoch 871/5000 | Loss 0.0390 | Win count 394
# Epoch 872/5000 | Loss 0.0982 | Win count 395
# Epoch 873/5000 | Loss 0.1123 | Win count 396
# Epoch 874/5000 | Loss 0.1388 | Win count 396
# Epoch 875/5000 | Loss 0.0418 | Win count 397
# Epoch 876/5000 | Loss 0.2036 | Win count 398
# Epoch 877/5000 | Loss 0.3918 | Win count 399
# Epoch 878/5000 | Loss 0.0786 | Win count 400
# Epoch 879/5000 | Loss 0.0810 | Win count 401
# Epoch 880/5000 | Loss 0.3929 | Win count 402
# Epoch 881/5000 | Loss 0.1178 | Win count 403
# Epoch 882/5000 | Loss 0.0446 | Win count 404
# Epoch 883/5000 | Loss 0.0833 | Win count 405
# Epoch 884/5000 | Loss 0.0898 | Win count 406
# Epoch 885/5000 | Loss 0.0379 | Win count 407
# Epoch 886/5000 | Loss 0.1009 | Win count 408
# Epoch 887/5000 | Loss 0.1385 | Win count 408
# Epoch 888/5000 | Loss 0.0426 | Win count 409
# Epoch 889/5000 | Loss 0.0637 | Win count 410
# Epoch 890/5000 | Loss 0.0951 | Win count 411
# Epoch 891/5000 | Loss 0.1415 | Win count 412
# Epoch 892/5000 | Loss 0.0549 | Win count 413
# Epoch 893/5000 | Loss 0.0298 | Win count 414
# Epoch 894/5000 | Loss 0.2149 | Win count 415
# Epoch 895/5000 | Loss 0.0386 | Win count 416
# Epoch 896/5000 | Loss 0.2618 | Win count 417
# Epoch 897/5000 | Loss 0.0788 | Win count 418
# Epoch 898/5000 | Loss 0.0153 | Win count 419
# Epoch 899/5000 | Loss 0.0394 | Win count 420
# Epoch 900/5000 | Loss 0.0515 | Win count 421
# Epoch 901/5000 | Loss 0.7886 | Win count 422
# Epoch 902/5000 | Loss 0.0049 | Win count 423
# Epoch 903/5000 | Loss 0.0484 | Win count 424
# Epoch 904/5000 | Loss 0.0225 | Win count 425
# Epoch 905/5000 | Loss 0.0309 | Win count 426
# Epoch 906/5000 | Loss 0.0224 | Win count 427
# Epoch 907/5000 | Loss 0.0383 | Win count 428
# Epoch 908/5000 | Loss 0.2042 | Win count 429
# Epoch 909/5000 | Loss 0.0543 | Win count 430
# Epoch 910/5000 | Loss 0.0435 | Win count 431
# Epoch 911/5000 | Loss 0.1340 | Win count 432
# Epoch 912/5000 | Loss 0.0593 | Win count 433
# Epoch 913/5000 | Loss 0.0294 | Win count 434
# Epoch 914/5000 | Loss 0.0260 | Win count 435
# Epoch 915/5000 | Loss 0.0132 | Win count 436
# Epoch 916/5000 | Loss 0.1453 | Win count 437
# Epoch 917/5000 | Loss 0.1338 | Win count 437
# Epoch 918/5000 | Loss 0.0682 | Win count 438
# Epoch 919/5000 | Loss 0.0849 | Win count 439
# Epoch 920/5000 | Loss 0.0150 | Win count 440
# Epoch 921/5000 | Loss 0.0869 | Win count 441
# Epoch 922/5000 | Loss 0.9525 | Win count 442
# Epoch 923/5000 | Loss 0.0301 | Win count 443
# Epoch 924/5000 | Loss 0.0591 | Win count 444
# Epoch 925/5000 | Loss 0.5558 | Win count 445
# Epoch 926/5000 | Loss 0.0977 | Win count 445
# Epoch 927/5000 | Loss 0.0380 | Win count 445
# Epoch 928/5000 | Loss 0.0123 | Win count 445
# Epoch 929/5000 | Loss 0.0381 | Win count 446
# Epoch 930/5000 | Loss 0.1292 | Win count 447
# Epoch 931/5000 | Loss 0.0449 | Win count 448
# Epoch 932/5000 | Loss 0.0497 | Win count 449
# Epoch 933/5000 | Loss 0.0744 | Win count 450
# Epoch 934/5000 | Loss 0.0098 | Win count 451
# Epoch 935/5000 | Loss 0.0797 | Win count 452
# Epoch 936/5000 | Loss 0.2187 | Win count 453
# Epoch 937/5000 | Loss 0.0867 | Win count 453
# Epoch 938/5000 | Loss 0.0997 | Win count 454
# Epoch 939/5000 | Loss 0.0255 | Win count 455
# Epoch 940/5000 | Loss 0.0379 | Win count 455
# Epoch 941/5000 | Loss 0.0334 | Win count 456
# Epoch 942/5000 | Loss 0.0675 | Win count 456
# Epoch 943/5000 | Loss 0.0522 | Win count 457
# Epoch 944/5000 | Loss 0.0236 | Win count 457
# Epoch 945/5000 | Loss 0.0439 | Win count 458
# Epoch 946/5000 | Loss 0.0296 | Win count 459
# Epoch 947/5000 | Loss 0.0459 | Win count 460
# Epoch 948/5000 | Loss 0.0602 | Win count 461
# Epoch 949/5000 | Loss 0.0084 | Win count 462
# Epoch 950/5000 | Loss 0.0282 | Win count 463
# Epoch 951/5000 | Loss 0.5448 | Win count 463
# Epoch 952/5000 | Loss 0.1486 | Win count 463
# Epoch 953/5000 | Loss 0.0205 | Win count 464
# Epoch 954/5000 | Loss 0.0112 | Win count 465
# Epoch 955/5000 | Loss 0.0243 | Win count 466
# Epoch 956/5000 | Loss 0.0680 | Win count 467
# Epoch 957/5000 | Loss 0.0159 | Win count 468
# Epoch 958/5000 | Loss 0.0300 | Win count 469
# Epoch 959/5000 | Loss 0.2398 | Win count 470
# Epoch 960/5000 | Loss 0.0405 | Win count 471
# Epoch 961/5000 | Loss 0.0219 | Win count 472
# Epoch 962/5000 | Loss 0.0169 | Win count 473
# Epoch 963/5000 | Loss 0.0289 | Win count 474
# Epoch 964/5000 | Loss 0.4413 | Win count 475
# Epoch 965/5000 | Loss 0.0771 | Win count 476
# Epoch 966/5000 | Loss 1.0060 | Win count 477
# Epoch 967/5000 | Loss 0.1643 | Win count 478
# Epoch 968/5000 | Loss 0.0281 | Win count 479
# Epoch 969/5000 | Loss 0.7510 | Win count 480
# Epoch 970/5000 | Loss 0.0449 | Win count 480
# Epoch 971/5000 | Loss 0.5444 | Win count 480
# Epoch 972/5000 | Loss 0.4579 | Win count 480
# Epoch 973/5000 | Loss 0.2925 | Win count 480
# Epoch 974/5000 | Loss 0.1501 | Win count 481
# Epoch 975/5000 | Loss 0.0402 | Win count 482
# Epoch 976/5000 | Loss 0.0616 | Win count 482
# Epoch 977/5000 | Loss 0.0390 | Win count 483
# Epoch 978/5000 | Loss 0.0305 | Win count 484
# Epoch 979/5000 | Loss 0.1950 | Win count 485
# Epoch 980/5000 | Loss 0.0154 | Win count 486
# Epoch 981/5000 | Loss 0.0695 | Win count 486
# Epoch 982/5000 | Loss 0.0347 | Win count 487
# Epoch 983/5000 | Loss 0.0057 | Win count 488
# Epoch 984/5000 | Loss 0.0271 | Win count 488
# Epoch 985/5000 | Loss 0.4648 | Win count 489
# Epoch 986/5000 | Loss 0.6232 | Win count 490
# Epoch 987/5000 | Loss 0.1137 | Win count 491
# Epoch 988/5000 | Loss 0.0239 | Win count 492
# Epoch 989/5000 | Loss 0.1440 | Win count 493
# Epoch 990/5000 | Loss 0.0805 | Win count 494
# Epoch 991/5000 | Loss 0.0894 | Win count 494
# Epoch 992/5000 | Loss 0.0225 | Win count 495
# Epoch 993/5000 | Loss 0.1146 | Win count 496
# Epoch 994/5000 | Loss 0.2277 | Win count 496
# Epoch 995/5000 | Loss 0.1758 | Win count 496
# Epoch 996/5000 | Loss 0.0530 | Win count 496
# Epoch 997/5000 | Loss 0.0921 | Win count 496
# Epoch 998/5000 | Loss 0.0517 | Win count 497
# Epoch 999/5000 | Loss 0.0445 | Win count 497
# Epoch 1000/5000 | Loss 0.7860 | Win count 498
# Epoch 1001/5000 | Loss 0.5901 | Win count 498
# Epoch 1002/5000 | Loss 0.0069 | Win count 499
# Epoch 1003/5000 | Loss 0.2215 | Win count 499
# Epoch 1004/5000 | Loss 0.0216 | Win count 500
# Epoch 1005/5000 | Loss 0.1029 | Win count 500
# Epoch 1006/5000 | Loss 0.3295 | Win count 501
# Epoch 1007/5000 | Loss 0.1561 | Win count 502
# Epoch 1008/5000 | Loss 0.1301 | Win count 503
# Epoch 1009/5000 | Loss 0.0330 | Win count 504
# Epoch 1010/5000 | Loss 0.1246 | Win count 505
# Epoch 1011/5000 | Loss 0.1123 | Win count 506
# Epoch 1012/5000 | Loss 0.0275 | Win count 507
# Epoch 1013/5000 | Loss 0.1044 | Win count 507
# Epoch 1014/5000 | Loss 0.0853 | Win count 508
# Epoch 1015/5000 | Loss 0.2263 | Win count 508
# Epoch 1016/5000 | Loss 0.0972 | Win count 509
# Epoch 1017/5000 | Loss 0.6339 | Win count 510
# Epoch 1018/5000 | Loss 0.4239 | Win count 511
# Epoch 1019/5000 | Loss 0.0794 | Win count 512
# Epoch 1020/5000 | Loss 0.0386 | Win count 512
# Epoch 1021/5000 | Loss 0.0251 | Win count 513
# Epoch 1022/5000 | Loss 0.0291 | Win count 513
# Epoch 1023/5000 | Loss 0.0411 | Win count 514
# Epoch 1024/5000 | Loss 0.0165 | Win count 514
# Epoch 1025/5000 | Loss 0.0792 | Win count 515
# Epoch 1026/5000 | Loss 0.0347 | Win count 515
# Epoch 1027/5000 | Loss 0.0241 | Win count 515
# Epoch 1028/5000 | Loss 0.0798 | Win count 515
# Epoch 1029/5000 | Loss 0.2207 | Win count 516
# Epoch 1030/5000 | Loss 0.0580 | Win count 517
# Epoch 1031/5000 | Loss 0.1323 | Win count 518
# Epoch 1032/5000 | Loss 0.6440 | Win count 518
# Epoch 1033/5000 | Loss 0.0198 | Win count 519
# Epoch 1034/5000 | Loss 0.1624 | Win count 519
# Epoch 1035/5000 | Loss 0.0142 | Win count 519
# Epoch 1036/5000 | Loss 0.0324 | Win count 519
# Epoch 1037/5000 | Loss 0.5243 | Win count 520
# Epoch 1038/5000 | Loss 0.1172 | Win count 521
# Epoch 1039/5000 | Loss 0.1919 | Win count 522
# Epoch 1040/5000 | Loss 0.0141 | Win count 523
# Epoch 1041/5000 | Loss 0.1288 | Win count 524
# Epoch 1042/5000 | Loss 0.0299 | Win count 524
# Epoch 1043/5000 | Loss 0.0124 | Win count 524
# Epoch 1044/5000 | Loss 0.1376 | Win count 525
# Epoch 1045/5000 | Loss 0.0512 | Win count 525
# Epoch 1046/5000 | Loss 0.1709 | Win count 526
# Epoch 1047/5000 | Loss 0.0400 | Win count 526
# Epoch 1048/5000 | Loss 0.0459 | Win count 527
# Epoch 1049/5000 | Loss 0.0268 | Win count 528
# Epoch 1050/5000 | Loss 0.0971 | Win count 529
# Epoch 1051/5000 | Loss 0.0804 | Win count 530
# Epoch 1052/5000 | Loss 0.0103 | Win count 531
# Epoch 1053/5000 | Loss 0.0739 | Win count 531
# Epoch 1054/5000 | Loss 0.1281 | Win count 532
# Epoch 1055/5000 | Loss 0.0471 | Win count 533
# Epoch 1056/5000 | Loss 0.3754 | Win count 534
# Epoch 1057/5000 | Loss 0.0838 | Win count 535
# Epoch 1058/5000 | Loss 0.1275 | Win count 536
# Epoch 1059/5000 | Loss 0.0136 | Win count 537
# Epoch 1060/5000 | Loss 0.0998 | Win count 538
# Epoch 1061/5000 | Loss 0.0282 | Win count 539
# Epoch 1062/5000 | Loss 0.1937 | Win count 539
# Epoch 1063/5000 | Loss 0.5899 | Win count 540
# Epoch 1064/5000 | Loss 0.1799 | Win count 541
# Epoch 1065/5000 | Loss 0.1500 | Win count 542
# Epoch 1066/5000 | Loss 0.0436 | Win count 543
# Epoch 1067/5000 | Loss 0.0553 | Win count 544
# Epoch 1068/5000 | Loss 0.0238 | Win count 545
# Epoch 1069/5000 | Loss 0.0499 | Win count 546
# Epoch 1070/5000 | Loss 0.0036 | Win count 547
# Epoch 1071/5000 | Loss 0.0313 | Win count 548
# Epoch 1072/5000 | Loss 0.1862 | Win count 549
# ...
# Epoch 4660/5000 | Loss 0.0015 | Win count 3869
# Epoch 4661/5000 | Loss 0.0062 | Win count 3870
# Epoch 4662/5000 | Loss 0.0012 | Win count 3871
# Epoch 4663/5000 | Loss 0.0029 | Win count 3872
# Epoch 4664/5000 | Loss 0.0121 | Win count 3873
# Epoch 4665/5000 | Loss 0.0029 | Win count 3874
# Epoch 4666/5000 | Loss 0.0010 | Win count 3875
# Epoch 4667/5000 | Loss 0.0012 | Win count 3876
# Epoch 4668/5000 | Loss 0.0031 | Win count 3877
# Epoch 4669/5000 | Loss 0.0013 | Win count 3878
# Epoch 4670/5000 | Loss 0.0025 | Win count 3879
# Epoch 4671/5000 | Loss 0.0017 | Win count 3879
# Epoch 4672/5000 | Loss 0.0023 | Win count 3879
# Epoch 4673/5000 | Loss 0.0028 | Win count 3880
# Epoch 4674/5000 | Loss 0.0013 | Win count 3881
# Epoch 4675/5000 | Loss 0.0356 | Win count 3882
# Epoch 4676/5000 | Loss 0.0037 | Win count 3883
# Epoch 4677/5000 | Loss 0.0025 | Win count 3884
# Epoch 4678/5000 | Loss 0.0018 | Win count 3885
# Epoch 4679/5000 | Loss 0.0048 | Win count 3886
# Epoch 4680/5000 | Loss 0.0049 | Win count 3887
# Epoch 4681/5000 | Loss 0.0013 | Win count 3888
# Epoch 4682/5000 | Loss 0.0080 | Win count 3889
# Epoch 4683/5000 | Loss 0.0034 | Win count 3890
# Epoch 4684/5000 | Loss 0.0011 | Win count 3891
# Epoch 4685/5000 | Loss 0.0015 | Win count 3892
# Epoch 4686/5000 | Loss 0.0017 | Win count 3893
# Epoch 4687/5000 | Loss 0.0034 | Win count 3894
# Epoch 4688/5000 | Loss 0.0014 | Win count 3895
# Epoch 4689/5000 | Loss 0.0016 | Win count 3896
# Epoch 4690/5000 | Loss 0.0012 | Win count 3897
# Epoch 4691/5000 | Loss 0.0015 | Win count 3898
# Epoch 4692/5000 | Loss 0.0846 | Win count 3899
# Epoch 4693/5000 | Loss 0.0057 | Win count 3900
# Epoch 4694/5000 | Loss 0.0014 | Win count 3901
# Epoch 4695/5000 | Loss 0.0048 | Win count 3902
# Epoch 4696/5000 | Loss 0.0049 | Win count 3902
# Epoch 4697/5000 | Loss 0.0018 | Win count 3903
# Epoch 4698/5000 | Loss 0.0012 | Win count 3904
# Epoch 4699/5000 | Loss 0.0033 | Win count 3905
# Epoch 4700/5000 | Loss 0.0053 | Win count 3906
# Epoch 4701/5000 | Loss 0.0016 | Win count 3907
# Epoch 4702/5000 | Loss 0.0013 | Win count 3908
# Epoch 4703/5000 | Loss 0.0031 | Win count 3909
# Epoch 4704/5000 | Loss 0.0013 | Win count 3910
# Epoch 4705/5000 | Loss 0.0013 | Win count 3911
# Epoch 4706/5000 | Loss 0.0005 | Win count 3912
# Epoch 4707/5000 | Loss 0.0022 | Win count 3913
# Epoch 4708/5000 | Loss 0.0027 | Win count 3914
# Epoch 4709/5000 | Loss 0.0026 | Win count 3915
# Epoch 4710/5000 | Loss 0.0019 | Win count 3916
# Epoch 4711/5000 | Loss 0.0011 | Win count 3917
# Epoch 4712/5000 | Loss 0.0017 | Win count 3918
# Epoch 4713/5000 | Loss 0.0008 | Win count 3919
# Epoch 4714/5000 | Loss 0.0020 | Win count 3920
# Epoch 4715/5000 | Loss 0.0026 | Win count 3921
# Epoch 4716/5000 | Loss 0.0012 | Win count 3922
# Epoch 4717/5000 | Loss 0.0010 | Win count 3923
# Epoch 4718/5000 | Loss 0.0198 | Win count 3924
# Epoch 4719/5000 | Loss 0.0022 | Win count 3925
# Epoch 4720/5000 | Loss 0.0056 | Win count 3926
# Epoch 4721/5000 | Loss 0.0006 | Win count 3927
# Epoch 4722/5000 | Loss 0.0082 | Win count 3928
# Epoch 4723/5000 | Loss 0.0083 | Win count 3928
# Epoch 4724/5000 | Loss 0.0063 | Win count 3929
# Epoch 4725/5000 | Loss 0.0054 | Win count 3930
# Epoch 4726/5000 | Loss 0.0100 | Win count 3930
# Epoch 4727/5000 | Loss 0.0017 | Win count 3931
# Epoch 4728/5000 | Loss 0.0068 | Win count 3932
# Epoch 4729/5000 | Loss 0.0032 | Win count 3933
# Epoch 4730/5000 | Loss 0.0069 | Win count 3934
# Epoch 4731/5000 | Loss 0.0069 | Win count 3935
# Epoch 4732/5000 | Loss 0.0056 | Win count 3936
# Epoch 4733/5000 | Loss 0.0016 | Win count 3937
# Epoch 4734/5000 | Loss 0.0014 | Win count 3938
# Epoch 4735/5000 | Loss 0.0032 | Win count 3939
# Epoch 4736/5000 | Loss 0.0013 | Win count 3940
# Epoch 4737/5000 | Loss 0.2478 | Win count 3941
# Epoch 4738/5000 | Loss 0.0528 | Win count 3942
# Epoch 4739/5000 | Loss 0.0015 | Win count 3943
# Epoch 4740/5000 | Loss 0.0039 | Win count 3944
# Epoch 4741/5000 | Loss 0.0271 | Win count 3945
# Epoch 4742/5000 | Loss 0.0085 | Win count 3946
# Epoch 4743/5000 | Loss 0.0117 | Win count 3947
# Epoch 4744/5000 | Loss 0.0036 | Win count 3948
# Epoch 4745/5000 | Loss 0.0033 | Win count 3949
# Epoch 4746/5000 | Loss 0.0017 | Win count 3950
# Epoch 4747/5000 | Loss 0.0056 | Win count 3951
# Epoch 4748/5000 | Loss 0.0154 | Win count 3952
# Epoch 4749/5000 | Loss 0.0056 | Win count 3953
# Epoch 4750/5000 | Loss 0.0025 | Win count 3954
# Epoch 4751/5000 | Loss 0.0054 | Win count 3955
# Epoch 4752/5000 | Loss 0.0014 | Win count 3956
# Epoch 4753/5000 | Loss 0.0030 | Win count 3957
# Epoch 4754/5000 | Loss 0.0066 | Win count 3958
# Epoch 4755/5000 | Loss 0.0721 | Win count 3959
# Epoch 4756/5000 | Loss 0.0044 | Win count 3960
# Epoch 4757/5000 | Loss 0.0024 | Win count 3961
# Epoch 4758/5000 | Loss 0.0017 | Win count 3962
# Epoch 4759/5000 | Loss 0.0051 | Win count 3963
# Epoch 4760/5000 | Loss 0.0039 | Win count 3964
# Epoch 4761/5000 | Loss 0.0044 | Win count 3965
# Epoch 4762/5000 | Loss 0.0049 | Win count 3966
# Epoch 4763/5000 | Loss 0.0053 | Win count 3967
# Epoch 4764/5000 | Loss 0.0012 | Win count 3968
# Epoch 4765/5000 | Loss 0.0018 | Win count 3969
# Epoch 4766/5000 | Loss 0.0061 | Win count 3970
# Epoch 4767/5000 | Loss 0.0007 | Win count 3971
# Epoch 4768/5000 | Loss 0.0008 | Win count 3972
# Epoch 4769/5000 | Loss 0.0035 | Win count 3973
# Epoch 4770/5000 | Loss 0.0230 | Win count 3974
# Epoch 4771/5000 | Loss 0.0041 | Win count 3975
# Epoch 4772/5000 | Loss 0.0017 | Win count 3976
# Epoch 4773/5000 | Loss 0.0050 | Win count 3977
# Epoch 4774/5000 | Loss 0.0216 | Win count 3978
# Epoch 4775/5000 | Loss 0.0043 | Win count 3979
# Epoch 4776/5000 | Loss 0.0242 | Win count 3980
# Epoch 4777/5000 | Loss 0.0043 | Win count 3981
# Epoch 4778/5000 | Loss 0.0079 | Win count 3982
# Epoch 4779/5000 | Loss 0.0015 | Win count 3983
# Epoch 4780/5000 | Loss 0.0022 | Win count 3984
# Epoch 4781/5000 | Loss 0.0015 | Win count 3984
# Epoch 4782/5000 | Loss 0.0006 | Win count 3985
# Epoch 4783/5000 | Loss 0.0025 | Win count 3986
# Epoch 4784/5000 | Loss 0.0014 | Win count 3987
# Epoch 4785/5000 | Loss 0.0028 | Win count 3988
# Epoch 4786/5000 | Loss 0.0025 | Win count 3989
# Epoch 4787/5000 | Loss 0.0011 | Win count 3990
# Epoch 4788/5000 | Loss 0.0013 | Win count 3991
# Epoch 4789/5000 | Loss 0.0020 | Win count 3992
# Epoch 4790/5000 | Loss 0.0018 | Win count 3993
# Epoch 4791/5000 | Loss 0.0012 | Win count 3994
# Epoch 4792/5000 | Loss 0.0015 | Win count 3995
# Epoch 4793/5000 | Loss 0.0042 | Win count 3996
# Epoch 4794/5000 | Loss 0.0027 | Win count 3997
# Epoch 4795/5000 | Loss 0.0015 | Win count 3998
# Epoch 4796/5000 | Loss 0.0012 | Win count 3999
# Epoch 4797/5000 | Loss 0.0023 | Win count 4000
# Epoch 4798/5000 | Loss 0.0017 | Win count 4001
# Epoch 4799/5000 | Loss 0.0015 | Win count 4002
# Epoch 4800/5000 | Loss 0.0008 | Win count 4003
# Epoch 4801/5000 | Loss 0.0022 | Win count 4004
# Epoch 4802/5000 | Loss 0.0008 | Win count 4005
# Epoch 4803/5000 | Loss 0.0008 | Win count 4006
# Epoch 4804/5000 | Loss 0.0008 | Win count 4007
# Epoch 4805/5000 | Loss 0.0183 | Win count 4008
# Epoch 4806/5000 | Loss 0.0054 | Win count 4009
# Epoch 4807/5000 | Loss 0.0014 | Win count 4010
# Epoch 4808/5000 | Loss 0.0009 | Win count 4011
# Epoch 4809/5000 | Loss 0.0241 | Win count 4012
# Epoch 4810/5000 | Loss 0.0093 | Win count 4013
# Epoch 4811/5000 | Loss 0.0027 | Win count 4014
# Epoch 4812/5000 | Loss 0.0031 | Win count 4014
# Epoch 4813/5000 | Loss 0.0017 | Win count 4015
# Epoch 4814/5000 | Loss 0.0018 | Win count 4016
# Epoch 4815/5000 | Loss 0.0079 | Win count 4016
# Epoch 4816/5000 | Loss 0.0009 | Win count 4017
# Epoch 4817/5000 | Loss 0.0013 | Win count 4018
# Epoch 4818/5000 | Loss 0.0005 | Win count 4019
# Epoch 4819/5000 | Loss 0.0037 | Win count 4020
# Epoch 4820/5000 | Loss 0.0005 | Win count 4021
# Epoch 4821/5000 | Loss 0.0026 | Win count 4022
# Epoch 4822/5000 | Loss 0.0022 | Win count 4023
# Epoch 4823/5000 | Loss 0.0006 | Win count 4023
# Epoch 4824/5000 | Loss 0.0269 | Win count 4024
# Epoch 4825/5000 | Loss 0.0009 | Win count 4025
# Epoch 4826/5000 | Loss 0.0070 | Win count 4026
# Epoch 4827/5000 | Loss 0.0043 | Win count 4027
# Epoch 4828/5000 | Loss 0.0032 | Win count 4028
# Epoch 4829/5000 | Loss 0.0012 | Win count 4029
# Epoch 4830/5000 | Loss 0.0009 | Win count 4030
# Epoch 4831/5000 | Loss 0.0011 | Win count 4031
# Epoch 4832/5000 | Loss 0.0037 | Win count 4031
# Epoch 4833/5000 | Loss 0.0014 | Win count 4032
# Epoch 4834/5000 | Loss 0.0016 | Win count 4033
# Epoch 4835/5000 | Loss 0.0020 | Win count 4034
# Epoch 4836/5000 | Loss 0.1327 | Win count 4035
# Epoch 4837/5000 | Loss 0.0044 | Win count 4036
# Epoch 4838/5000 | Loss 0.0101 | Win count 4037
# Epoch 4839/5000 | Loss 0.0274 | Win count 4038
# Epoch 4840/5000 | Loss 0.0129 | Win count 4039
# Epoch 4841/5000 | Loss 0.0042 | Win count 4040
# Epoch 4842/5000 | Loss 0.0181 | Win count 4041
# Epoch 4843/5000 | Loss 0.0050 | Win count 4042
# Epoch 4844/5000 | Loss 0.0020 | Win count 4043
# Epoch 4845/5000 | Loss 0.0088 | Win count 4044
# Epoch 4846/5000 | Loss 0.0043 | Win count 4045
# Epoch 4847/5000 | Loss 0.0012 | Win count 4046
# Epoch 4848/5000 | Loss 0.0039 | Win count 4047
# Epoch 4849/5000 | Loss 0.0007 | Win count 4048
# Epoch 4850/5000 | Loss 0.0016 | Win count 4049
# Epoch 4851/5000 | Loss 0.0844 | Win count 4050
# Epoch 4852/5000 | Loss 0.0156 | Win count 4051
# Epoch 4853/5000 | Loss 0.0431 | Win count 4052
# Epoch 4854/5000 | Loss 0.0299 | Win count 4052
# Epoch 4855/5000 | Loss 0.0049 | Win count 4053
# Epoch 4856/5000 | Loss 0.0070 | Win count 4054
# Epoch 4857/5000 | Loss 0.0097 | Win count 4055
# Epoch 4858/5000 | Loss 0.0324 | Win count 4056
# Epoch 4859/5000 | Loss 0.0834 | Win count 4057
# Epoch 4860/5000 | Loss 0.0397 | Win count 4058
# Epoch 4861/5000 | Loss 0.0121 | Win count 4059
# Epoch 4862/5000 | Loss 0.0195 | Win count 4060
# Epoch 4863/5000 | Loss 0.0025 | Win count 4061
# Epoch 4864/5000 | Loss 0.0030 | Win count 4062
# Epoch 4865/5000 | Loss 0.0139 | Win count 4062
# Epoch 4866/5000 | Loss 0.0357 | Win count 4063
# Epoch 4867/5000 | Loss 0.4069 | Win count 4063
# Epoch 4868/5000 | Loss 0.1488 | Win count 4064
# Epoch 4869/5000 | Loss 0.1235 | Win count 4065
# Epoch 4870/5000 | Loss 0.0528 | Win count 4066
# Epoch 4871/5000 | Loss 0.0283 | Win count 4067
# Epoch 4872/5000 | Loss 0.0322 | Win count 4068
# Epoch 4873/5000 | Loss 0.0134 | Win count 4069
# Epoch 4874/5000 | Loss 0.0151 | Win count 4070
# Epoch 4875/5000 | Loss 0.2124 | Win count 4071
# Epoch 4876/5000 | Loss 0.0150 | Win count 4072
# Epoch 4877/5000 | Loss 0.0367 | Win count 4073
# Epoch 4878/5000 | Loss 0.0369 | Win count 4074
# Epoch 4879/5000 | Loss 0.0889 | Win count 4075
# Epoch 4880/5000 | Loss 0.0064 | Win count 4076
# Epoch 4881/5000 | Loss 0.0033 | Win count 4077
# Epoch 4882/5000 | Loss 0.0136 | Win count 4078
# Epoch 4883/5000 | Loss 0.1294 | Win count 4079
# Epoch 4884/5000 | Loss 0.0443 | Win count 4079
# Epoch 4885/5000 | Loss 0.0030 | Win count 4080
# Epoch 4886/5000 | Loss 0.0085 | Win count 4081
# Epoch 4887/5000 | Loss 0.0059 | Win count 4082
# Epoch 4888/5000 | Loss 0.0072 | Win count 4083
# Epoch 4889/5000 | Loss 0.0198 | Win count 4084
# Epoch 4890/5000 | Loss 0.0677 | Win count 4085
# Epoch 4891/5000 | Loss 0.0274 | Win count 4086
# Epoch 4892/5000 | Loss 0.0016 | Win count 4087
# Epoch 4893/5000 | Loss 0.0113 | Win count 4088
# Epoch 4894/5000 | Loss 0.0098 | Win count 4089
# Epoch 4895/5000 | Loss 0.0027 | Win count 4090
# Epoch 4896/5000 | Loss 0.0046 | Win count 4090
# Epoch 4897/5000 | Loss 0.0071 | Win count 4091
# Epoch 4898/5000 | Loss 0.0045 | Win count 4092
# Epoch 4899/5000 | Loss 0.0120 | Win count 4092
# Epoch 4900/5000 | Loss 0.0048 | Win count 4093
# Epoch 4901/5000 | Loss 0.1603 | Win count 4094
# Epoch 4902/5000 | Loss 0.0713 | Win count 4095
# Epoch 4903/5000 | Loss 0.0134 | Win count 4095
# Epoch 4904/5000 | Loss 0.0028 | Win count 4096
# Epoch 4905/5000 | Loss 0.0039 | Win count 4097
# Epoch 4906/5000 | Loss 0.0075 | Win count 4098
# Epoch 4907/5000 | Loss 0.1371 | Win count 4099
# Epoch 4908/5000 | Loss 0.0155 | Win count 4100
# Epoch 4909/5000 | Loss 0.0087 | Win count 4101
# Epoch 4910/5000 | Loss 0.0062 | Win count 4102
# Epoch 4911/5000 | Loss 0.0057 | Win count 4103
# Epoch 4912/5000 | Loss 0.2802 | Win count 4104
# Epoch 4913/5000 | Loss 0.0299 | Win count 4105
# Epoch 4914/5000 | Loss 0.1246 | Win count 4106
# Epoch 4915/5000 | Loss 0.0083 | Win count 4107
# Epoch 4916/5000 | Loss 0.0089 | Win count 4108
# Epoch 4917/5000 | Loss 0.0029 | Win count 4109
# Epoch 4918/5000 | Loss 0.0054 | Win count 4110
# Epoch 4919/5000 | Loss 0.0050 | Win count 4111
# Epoch 4920/5000 | Loss 0.0028 | Win count 4112
# Epoch 4921/5000 | Loss 0.0977 | Win count 4113
# Epoch 4922/5000 | Loss 0.0082 | Win count 4114
# Epoch 4923/5000 | Loss 0.0305 | Win count 4115
# Epoch 4924/5000 | Loss 0.0080 | Win count 4116
# Epoch 4925/5000 | Loss 0.0387 | Win count 4117
# Epoch 4926/5000 | Loss 0.0089 | Win count 4118
# Epoch 4927/5000 | Loss 0.0044 | Win count 4119
# Epoch 4928/5000 | Loss 0.1456 | Win count 4120
# Epoch 4929/5000 | Loss 0.0139 | Win count 4121
# Epoch 4930/5000 | Loss 0.2058 | Win count 4122
# Epoch 4931/5000 | Loss 0.3580 | Win count 4123
# Epoch 4932/5000 | Loss 0.0552 | Win count 4124
# Epoch 4933/5000 | Loss 0.0530 | Win count 4124
# Epoch 4934/5000 | Loss 0.4978 | Win count 4125
# Epoch 4935/5000 | Loss 0.0270 | Win count 4126
# Epoch 4936/5000 | Loss 0.0197 | Win count 4127
# Epoch 4937/5000 | Loss 0.0421 | Win count 4128
# Epoch 4938/5000 | Loss 0.0628 | Win count 4129
# Epoch 4939/5000 | Loss 0.3287 | Win count 4130
# Epoch 4940/5000 | Loss 0.0114 | Win count 4130
# Epoch 4941/5000 | Loss 0.0171 | Win count 4131
# Epoch 4942/5000 | Loss 0.0599 | Win count 4132
# Epoch 4943/5000 | Loss 0.0120 | Win count 4133
# Epoch 4944/5000 | Loss 0.0491 | Win count 4134
# Epoch 4945/5000 | Loss 0.0358 | Win count 4135
# Epoch 4946/5000 | Loss 0.0099 | Win count 4136
# Epoch 4947/5000 | Loss 0.1184 | Win count 4137
# Epoch 4948/5000 | Loss 0.0096 | Win count 4138
# Epoch 4949/5000 | Loss 0.0336 | Win count 4139
# Epoch 4950/5000 | Loss 0.0555 | Win count 4140
# Epoch 4951/5000 | Loss 0.0083 | Win count 4141
# Epoch 4952/5000 | Loss 0.0136 | Win count 4142
# Epoch 4953/5000 | Loss 0.0097 | Win count 4143
# Epoch 4954/5000 | Loss 0.0547 | Win count 4143
# Epoch 4955/5000 | Loss 0.0203 | Win count 4144
# Epoch 4956/5000 | Loss 0.0101 | Win count 4145
# Epoch 4957/5000 | Loss 0.0292 | Win count 4146
# Epoch 4958/5000 | Loss 0.0092 | Win count 4147
# Epoch 4959/5000 | Loss 0.0051 | Win count 4148
# Epoch 4960/5000 | Loss 0.0039 | Win count 4149
# Epoch 4961/5000 | Loss 0.0133 | Win count 4149
# Epoch 4962/5000 | Loss 0.0097 | Win count 4150
# Epoch 4963/5000 | Loss 0.0031 | Win count 4151
# Epoch 4964/5000 | Loss 0.0046 | Win count 4152
# Epoch 4965/5000 | Loss 0.0244 | Win count 4153
# Epoch 4966/5000 | Loss 0.0075 | Win count 4154
# Epoch 4967/5000 | Loss 0.0036 | Win count 4155
# Epoch 4968/5000 | Loss 0.0054 | Win count 4156
# Epoch 4969/5000 | Loss 0.0082 | Win count 4157
# Epoch 4970/5000 | Loss 0.2397 | Win count 4158
# Epoch 4971/5000 | Loss 0.0349 | Win count 4159
# Epoch 4972/5000 | Loss 0.0255 | Win count 4160
# Epoch 4973/5000 | Loss 0.0078 | Win count 4160
# Epoch 4974/5000 | Loss 0.5104 | Win count 4161
# Epoch 4975/5000 | Loss 0.0061 | Win count 4162
# Epoch 4976/5000 | Loss 0.0044 | Win count 4163
# Epoch 4977/5000 | Loss 0.0080 | Win count 4164
# Epoch 4978/5000 | Loss 0.0054 | Win count 4165
# Epoch 4979/5000 | Loss 0.0042 | Win count 4166
# Epoch 4980/5000 | Loss 0.0442 | Win count 4167
# Epoch 4981/5000 | Loss 0.4700 | Win count 4168
# Epoch 4982/5000 | Loss 0.0118 | Win count 4169
# Epoch 4983/5000 | Loss 0.0067 | Win count 4169
# Epoch 4984/5000 | Loss 0.0027 | Win count 4170
# Epoch 4985/5000 | Loss 0.0131 | Win count 4171
# Epoch 4986/5000 | Loss 0.0027 | Win count 4172
# Epoch 4987/5000 | Loss 0.0084 | Win count 4173
# Epoch 4988/5000 | Loss 0.0067 | Win count 4174
# Epoch 4989/5000 | Loss 0.0032 | Win count 4175
# Epoch 4990/5000 | Loss 0.0081 | Win count 4176
# Epoch 4991/5000 | Loss 0.0029 | Win count 4177
# Epoch 4992/5000 | Loss 0.0024 | Win count 4178
# Epoch 4993/5000 | Loss 0.0164 | Win count 4179
# Epoch 4994/5000 | Loss 0.0044 | Win count 4180
# Epoch 4995/5000 | Loss 0.0077 | Win count 4181
# Epoch 4996/5000 | Loss 0.0033 | Win count 4182
# Epoch 4997/5000 | Loss 0.0029 | Win count 4183
# Epoch 4998/5000 | Loss 0.0029 | Win count 4184
# Epoch 4999/5000 | Loss 0.0124 | Win count 4185
# Training done!

# %% [markdown]
# # Testing

# %%
def test(model):
    # this function lets a pretrained model play the game to evaluate how well it is doing
    global last_frame_time
    plt.ion()
    # define env / game
    env = Catch(grid_size)
    # c is a simple counter variable keeping track of how much we train
    c = 0
    # reset the last frame time (we start from 0)
    last_frame_time = 0
    # reset score
    points = 0
    # for training we are playing the game 10 times
    for e in range(10):
        loss = 0.
        # reset the game
        env.reset()
        # the game is not over
        game_over = False
        # get initial input
        input_t = env.observe()
        #display_screen(3, points, input_t)
        c += 1
        while not game_over:
            # the learner is acting on the last observed game screen
            # input_t is a vector containing representing the game screen
            input_tm1 = input_t
            # feed the learner the current status and get the expected rewards for different actions from it
            q = model.predict(input_tm1)
            # select the action with the highest expected reward
            action = np.argmax(q[0])
            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)
            # update our score
            points += reward
            display_screen(action, points, input_t)
            c += 1
